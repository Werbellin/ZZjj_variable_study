# %%
#%pylab inline
# %matplotlib inline
from array import array
import numpy as np
from numpy.random import RandomState
import matplotlib.pyplot as plt
from root_numpy.tmva import add_classification_events, evaluate_reader
from ROOT import TMVA, TFile, TCut
# Classify the test dataset with the classifier
reader = TMVA.Reader()
from root_numpy import root2array, rec2array
from sklearn.metrics import roc_curve, auc
from sklearn.metrics.ranking import _binary_clf_curve
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

from MVA_utils import *
from IPython.core.pylabtools import figsize

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

import pickle
from sklearn.externals import joblib
import xgboost as xgb
# Out:
# Welcome to ROOTaaS 6.06/00

# %%
tree_prefix = '/home/llr/cms/pigard/ZZjj_generator_study/'

branch_names = ['m_jj', 
                'dEta_tj', 
                'm_4l',
                'Z1_zepp', 
                'Z2_zepp', 
                'dPhi_Z1_Z2', 
                'tj1_eta_x_tj2_eta', 
                'costhetastar', 
                'phi', 
                'costheta1', 
                'costheta2', 
                'phi1',
                'vbf_costhetastar',
                'vbf_costheta1',
                'vbf_costheta2',
                'vbf_phi',
                'vbf_phi1',
                'qv1',
                'qv2',
                'jet_Dphi',
                'tj1_qg',
                'tj2_qg',
                'ntj_n',
                'ntj_scalar_sum_pt',
                'ntj_central_n',
                'ntj_central_scalar_sum_pt',
                'max_4l_eta',
                'tj_min_eta',
                'tj_max_eta',
                'R_vector',
                'R_scalar',
                
                'rel_pt_hard',
                'tj_delta_rel',
                'tj_sum_abs_eta',
                'tj2_eta',
                'tj1_eta',
                'tj2_pt', #is actually Z2
                'tj1_pt',#is actually Z1
                'm_jj_over_dEta_tj',
                
               ]

signal = root2array(tree_prefix + 'zzjj_ewk_tight_v6_ZZ4lAnalysis_MVA_tree.root',
                    "test",
                    branch_names)


backgr = root2array(tree_prefix + 'zzjj_qcd_tight_v6_ZZ4lAnalysis_MVA_tree.root',
                    "test",
                    branch_names)

# %%
classic_vbf = ['m_jj', 
                'dEta_tj', 
                'm_4l',
                'Z1_zepp', 
                'Z2_zepp', 
                'dPhi_Z1_Z2', 
                'tj1_eta_x_tj2_eta']
decay_angles = ['costhetastar', 
                'phi', 
                'costheta1', 
                'costheta2', 
                'phi1',
                ]


prod_angles = [
                'vbf_costhetastar',
                'vbf_costheta1',
                'vbf_costheta2',
                'vbf_phi',
                'vbf_phi1',
                'qv1',
                'qv2']

hadronic_activity = [  'ntj_n',
                'ntj_scalar_sum_pt',
                'ntj_central_n',
                'ntj_central_scalar_sum_pt']
new_var = [     'max_4l_eta',
                'tj_min_eta',
                'tj_max_eta',
                'rel_pt_hard',
                'tj_delta_rel',
                'tj_sum_abs_eta',
                'tj2_eta',
                'tj1_eta',
                'tj2_pt', #is actually Z2
                'tj1_pt',#is actually Z1
                'm_jj_over_dEta_tj'
          ]


qg = ['tj1_qg', 'tj2_qg']

print 'len: ', len(classic_vbf + new_var + hadronic_activity + qg + prod_angles + decay_angles)
# Out:
# len:  36

# %%
#prune_1 = classic_vbf + new_var + hadronic_activity + qg
#prine_1_remove = ['tj1_eta_x_tj2_eta', 'max_4l_eta', 'tj_sum_abs_eta', 'tj_min_eta', 'dPhi_Z1_Z2', 'tj2_eta']
#prune_1 = [var for var in prune_1 if var not in prine_1_remove]

var = classic_vbf + new_var + hadronic_activity + qg #+ prod_angles + decay_angles 
red_back = rec2array(backgr[var])
red_sig = rec2array(signal[var])
        
X = np.concatenate((red_sig, red_back))
y = np.concatenate((np.ones(red_sig.shape[0]) ,
                            np.zeros(red_back.shape[0])))
        
    
#X_dev,X_eval, y_dev,y_eval = train_test_split(X, y, test_size=0.33, random_state=42)
X_train,X_test, y_train,y_test = train_test_split(X, y, test_size=0.93, random_state=492)

# %%
#gbdt = GradientBoostingClassifier(n_estimators=800, learning_rate =.1, max_depth=4, random_state=0)
gbdt = GradientBoostingClassifier(n_estimators=1600, learning_rate =.01, max_depth=8, random_state=0, min_samples_leaf = 800)
#gbm = xgb.XGBClassifier(max_depth=8, n_estimators=1000, learning_rate=0.01, nthread=10)


dt = DecisionTreeClassifier(max_depth=1,
                            min_samples_leaf=0.05*len(X_train))
ada = AdaBoostClassifier(dt,
                         algorithm='SAMME',
                         n_estimators=800,
                         learning_rate=0.5)
est = gbdt
est.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=8, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=800, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1600,
#               presort='auto', random_state=0, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
joblib.dump(est, 'gbdt_full_20160316.pkl')
#est = joblib.load('/home/llr/cms/pigard/ZZjj_generator_study/gbdt_best.pkl') 
#pickle.load(gbdt, open("/home/llr/cms/pigard/ZZjj_generator_study/gbdt_best.pkl", "rb" ))


#est_decisions = est.predict_proba(X_test)[:, 1]
#est_fpr, est_tpr, thresholds = roc_curve(y_test, est_decisions)
# Out:
# ['gbdt_full_20160316.pkl',
#  'gbdt_full_20160316.pkl_01.npy',
#  'gbdt_full_20160316.pkl_02.npy',
#  'gbdt_full_20160316.pkl_03.npy',
#  'gbdt_full_20160316.pkl_04.npy',
#  'gbdt_full_20160316.pkl_05.npy',
#  'gbdt_full_20160316.pkl_06.npy',
#  'gbdt_full_20160316.pkl_07.npy',
#  'gbdt_full_20160316.pkl_08.npy',
#  'gbdt_full_20160316.pkl_09.npy',
#  'gbdt_full_20160316.pkl_10.npy',
#  'gbdt_full_20160316.pkl_11.npy',
#  'gbdt_full_20160316.pkl_12.npy',
#  'gbdt_full_20160316.pkl_13.npy',
#  'gbdt_full_20160316.pkl_14.npy',
#  'gbdt_full_20160316.pkl_15.npy',
#  'gbdt_full_20160316.pkl_16.npy',
#  'gbdt_full_20160316.pkl_17.npy',
#  'gbdt_full_20160316.pkl_18.npy',
#  'gbdt_full_20160316.pkl_19.npy',
#  'gbdt_full_20160316.pkl_20.npy',
#  'gbdt_full_20160316.pkl_21.npy',
#  'gbdt_full_20160316.pkl_22.npy',
#  'gbdt_full_20160316.pkl_23.npy',
#  'gbdt_full_20160316.pkl_24.npy',
#  'gbdt_full_20160316.pkl_25.npy',
#  'gbdt_full_20160316.pkl_26.npy',
#  'gbdt_full_20160316.pkl_27.npy',
#  'gbdt_full_20160316.pkl_28.npy',
#  'gbdt_full_20160316.pkl_29.npy',
#  'gbdt_full_20160316.pkl_30.npy',
#  'gbdt_full_20160316.pkl_31.npy',
#  'gbdt_full_20160316.pkl_32.npy',
#  'gbdt_full_20160316.pkl_33.npy',
#  'gbdt_full_20160316.pkl_34.npy',
#  'gbdt_full_20160316.pkl_35.npy',
#  'gbdt_full_20160316.pkl_36.npy',
#  'gbdt_full_20160316.pkl_37.npy',
#  'gbdt_full_20160316.pkl_38.npy',
#  'gbdt_full_20160316.pkl_39.npy',
#  'gbdt_full_20160316.pkl_40.npy',
#  'gbdt_full_20160316.pkl_41.npy',
#  'gbdt_full_20160316.pkl_42.npy',
#  'gbdt_full_20160316.pkl_43.npy',
#  'gbdt_full_20160316.pkl_44.npy',
#  'gbdt_full_20160316.pkl_45.npy',
#  'gbdt_full_20160316.pkl_46.npy',
#  'gbdt_full_20160316.pkl_47.npy',
#  'gbdt_full_20160316.pkl_48.npy',
#  'gbdt_full_20160316.pkl_49.npy',
#  'gbdt_full_20160316.pkl_50.npy',
#  'gbdt_full_20160316.pkl_51.npy',
#  'gbdt_full_20160316.pkl_52.npy',
#  'gbdt_full_20160316.pkl_53.npy',
#  'gbdt_full_20160316.pkl_54.npy',
#  'gbdt_full_20160316.pkl_55.npy',
#  'gbdt_full_20160316.pkl_56.npy',
#  'gbdt_full_20160316.pkl_57.npy',
#  'gbdt_full_20160316.pkl_58.npy',
#  'gbdt_full_20160316.pkl_59.npy',
#  'gbdt_full_20160316.pkl_60.npy',
#  'gbdt_full_20160316.pkl_61.npy',
#  'gbdt_full_20160316.pkl_62.npy',
#  'gbdt_full_20160316.pkl_63.npy',
#  'gbdt_full_20160316.pkl_64.npy',
#  'gbdt_full_20160316.pkl_65.npy',
#  'gbdt_full_20160316.pkl_66.npy',
#  'gbdt_full_20160316.pkl_67.npy',
#  'gbdt_full_20160316.pkl_68.npy',
#  'gbdt_full_20160316.pkl_69.npy',
#  'gbdt_full_20160316.pkl_70.npy',
#  'gbdt_full_20160316.pkl_71.npy',
#  'gbdt_full_20160316.pkl_72.npy',
#  'gbdt_full_20160316.pkl_73.npy',
#  'gbdt_full_20160316.pkl_74.npy',
#  'gbdt_full_20160316.pkl_75.npy',
#  'gbdt_full_20160316.pkl_76.npy',
#  'gbdt_full_20160316.pkl_77.npy',
#  'gbdt_full_20160316.pkl_78.npy',
#  'gbdt_full_20160316.pkl_79.npy',
#  'gbdt_full_20160316.pkl_80.npy',
#  'gbdt_full_20160316.pkl_81.npy',
#  'gbdt_full_20160316.pkl_82.npy',
#  'gbdt_full_20160316.pkl_83.npy',
#  'gbdt_full_20160316.pkl_84.npy',
#  'gbdt_full_20160316.pkl_85.npy',
#  'gbdt_full_20160316.pkl_86.npy',
#  'gbdt_full_20160316.pkl_87.npy',
#  'gbdt_full_20160316.pkl_88.npy',
#  'gbdt_full_20160316.pkl_89.npy',
#  'gbdt_full_20160316.pkl_90.npy',
#  'gbdt_full_20160316.pkl_91.npy',
#  'gbdt_full_20160316.pkl_92.npy',
#  'gbdt_full_20160316.pkl_93.npy',
#  'gbdt_full_20160316.pkl_94.npy',
#  'gbdt_full_20160316.pkl_95.npy',
#  'gbdt_full_20160316.pkl_96.npy',
#  'gbdt_full_20160316.pkl_97.npy',
#  'gbdt_full_20160316.pkl_98.npy',
#  'gbdt_full_20160316.pkl_99.npy',
#  'gbdt_full_20160316.pkl_100.npy',
#  'gbdt_full_20160316.pkl_101.npy',
#  'gbdt_full_20160316.pkl_102.npy',
#  'gbdt_full_20160316.pkl_103.npy',
#  'gbdt_full_20160316.pkl_104.npy',
#  'gbdt_full_20160316.pkl_105.npy',
#  'gbdt_full_20160316.pkl_106.npy',
#  'gbdt_full_20160316.pkl_107.npy',
#  'gbdt_full_20160316.pkl_108.npy',
#  'gbdt_full_20160316.pkl_109.npy',
#  'gbdt_full_20160316.pkl_110.npy',
#  'gbdt_full_20160316.pkl_111.npy',
#  'gbdt_full_20160316.pkl_112.npy',
#  'gbdt_full_20160316.pkl_113.npy',
#  'gbdt_full_20160316.pkl_114.npy',
#  'gbdt_full_20160316.pkl_115.npy',
#  'gbdt_full_20160316.pkl_116.npy',
#  'gbdt_full_20160316.pkl_117.npy',
#  'gbdt_full_20160316.pkl_118.npy',
#  'gbdt_full_20160316.pkl_119.npy',
#  'gbdt_full_20160316.pkl_120.npy',
#  'gbdt_full_20160316.pkl_121.npy',
#  'gbdt_full_20160316.pkl_122.npy',
#  'gbdt_full_20160316.pkl_123.npy',
#  'gbdt_full_20160316.pkl_124.npy',
#  'gbdt_full_20160316.pkl_125.npy',
#  'gbdt_full_20160316.pkl_126.npy',
#  'gbdt_full_20160316.pkl_127.npy',
#  'gbdt_full_20160316.pkl_128.npy',
#  'gbdt_full_20160316.pkl_129.npy',
#  'gbdt_full_20160316.pkl_130.npy',
#  'gbdt_full_20160316.pkl_131.npy',
#  'gbdt_full_20160316.pkl_132.npy',
#  'gbdt_full_20160316.pkl_133.npy',
#  'gbdt_full_20160316.pkl_134.npy',
#  'gbdt_full_20160316.pkl_135.npy',
#  'gbdt_full_20160316.pkl_136.npy',
#  'gbdt_full_20160316.pkl_137.npy',
#  'gbdt_full_20160316.pkl_138.npy',
#  'gbdt_full_20160316.pkl_139.npy',
#  'gbdt_full_20160316.pkl_140.npy',
#  'gbdt_full_20160316.pkl_141.npy',
#  'gbdt_full_20160316.pkl_142.npy',
#  'gbdt_full_20160316.pkl_143.npy',
#  'gbdt_full_20160316.pkl_144.npy',
#  'gbdt_full_20160316.pkl_145.npy',
#  'gbdt_full_20160316.pkl_146.npy',
#  'gbdt_full_20160316.pkl_147.npy',
#  'gbdt_full_20160316.pkl_148.npy',
#  'gbdt_full_20160316.pkl_149.npy',
#  'gbdt_full_20160316.pkl_150.npy',
#  'gbdt_full_20160316.pkl_151.npy',
#  'gbdt_full_20160316.pkl_152.npy',
#  'gbdt_full_20160316.pkl_153.npy',
#  'gbdt_full_20160316.pkl_154.npy',
#  'gbdt_full_20160316.pkl_155.npy',
#  'gbdt_full_20160316.pkl_156.npy',
#  'gbdt_full_20160316.pkl_157.npy',
#  'gbdt_full_20160316.pkl_158.npy',
#  'gbdt_full_20160316.pkl_159.npy',
#  'gbdt_full_20160316.pkl_160.npy',
#  'gbdt_full_20160316.pkl_161.npy',
#  'gbdt_full_20160316.pkl_162.npy',
#  'gbdt_full_20160316.pkl_163.npy',
#  'gbdt_full_20160316.pkl_164.npy',
#  'gbdt_full_20160316.pkl_165.npy',
#  'gbdt_full_20160316.pkl_166.npy',
#  'gbdt_full_20160316.pkl_167.npy',
#  'gbdt_full_20160316.pkl_168.npy',
#  'gbdt_full_20160316.pkl_169.npy',
#  'gbdt_full_20160316.pkl_170.npy',
#  'gbdt_full_20160316.pkl_171.npy',
#  'gbdt_full_20160316.pkl_172.npy',
#  'gbdt_full_20160316.pkl_173.npy',
#  'gbdt_full_20160316.pkl_174.npy',
#  'gbdt_full_20160316.pkl_175.npy',
#  'gbdt_full_20160316.pkl_176.npy',
#  'gbdt_full_20160316.pkl_177.npy',
#  'gbdt_full_20160316.pkl_178.npy',
#  'gbdt_full_20160316.pkl_179.npy',
#  'gbdt_full_20160316.pkl_180.npy',
#  'gbdt_full_20160316.pkl_181.npy',
#  'gbdt_full_20160316.pkl_182.npy',
#  'gbdt_full_20160316.pkl_183.npy',
#  'gbdt_full_20160316.pkl_184.npy',
#  'gbdt_full_20160316.pkl_185.npy',
#  'gbdt_full_20160316.pkl_186.npy',
#  'gbdt_full_20160316.pkl_187.npy',
#  'gbdt_full_20160316.pkl_188.npy',
#  'gbdt_full_20160316.pkl_189.npy',
#  'gbdt_full_20160316.pkl_190.npy',
#  'gbdt_full_20160316.pkl_191.npy',
#  'gbdt_full_20160316.pkl_192.npy',
#  'gbdt_full_20160316.pkl_193.npy',
#  'gbdt_full_20160316.pkl_194.npy',
#  'gbdt_full_20160316.pkl_195.npy',
#  'gbdt_full_20160316.pkl_196.npy',
#  'gbdt_full_20160316.pkl_197.npy',
#  'gbdt_full_20160316.pkl_198.npy',
#  'gbdt_full_20160316.pkl_199.npy',
#  'gbdt_full_20160316.pkl_200.npy',
#  'gbdt_full_20160316.pkl_201.npy',
#  'gbdt_full_20160316.pkl_202.npy',
#  'gbdt_full_20160316.pkl_203.npy',
#  'gbdt_full_20160316.pkl_204.npy',
#  'gbdt_full_20160316.pkl_205.npy',
#  'gbdt_full_20160316.pkl_206.npy',
#  'gbdt_full_20160316.pkl_207.npy',
#  'gbdt_full_20160316.pkl_208.npy',
#  'gbdt_full_20160316.pkl_209.npy',
#  'gbdt_full_20160316.pkl_210.npy',
#  'gbdt_full_20160316.pkl_211.npy',
#  'gbdt_full_20160316.pkl_212.npy',
#  'gbdt_full_20160316.pkl_213.npy',
#  'gbdt_full_20160316.pkl_214.npy',
#  'gbdt_full_20160316.pkl_215.npy',
#  'gbdt_full_20160316.pkl_216.npy',
#  'gbdt_full_20160316.pkl_217.npy',
#  'gbdt_full_20160316.pkl_218.npy',
#  'gbdt_full_20160316.pkl_219.npy',
#  'gbdt_full_20160316.pkl_220.npy',
#  'gbdt_full_20160316.pkl_221.npy',
#  'gbdt_full_20160316.pkl_222.npy',
#  'gbdt_full_20160316.pkl_223.npy',
#  'gbdt_full_20160316.pkl_224.npy',
#  'gbdt_full_20160316.pkl_225.npy',
#  'gbdt_full_20160316.pkl_226.npy',
#  'gbdt_full_20160316.pkl_227.npy',
#  'gbdt_full_20160316.pkl_228.npy',
#  'gbdt_full_20160316.pkl_229.npy',
#  'gbdt_full_20160316.pkl_230.npy',
#  'gbdt_full_20160316.pkl_231.npy',
#  'gbdt_full_20160316.pkl_232.npy',
#  'gbdt_full_20160316.pkl_233.npy',
#  'gbdt_full_20160316.pkl_234.npy',
#  'gbdt_full_20160316.pkl_235.npy',
#  'gbdt_full_20160316.pkl_236.npy',
#  'gbdt_full_20160316.pkl_237.npy',
#  'gbdt_full_20160316.pkl_238.npy',
#  'gbdt_full_20160316.pkl_239.npy',
#  'gbdt_full_20160316.pkl_240.npy',
#  'gbdt_full_20160316.pkl_241.npy',
#  'gbdt_full_20160316.pkl_242.npy',
#  'gbdt_full_20160316.pkl_243.npy',
#  'gbdt_full_20160316.pkl_244.npy',
#  'gbdt_full_20160316.pkl_245.npy',
#  'gbdt_full_20160316.pkl_246.npy',
#  'gbdt_full_20160316.pkl_247.npy',
#  'gbdt_full_20160316.pkl_248.npy',
#  'gbdt_full_20160316.pkl_249.npy',
#  'gbdt_full_20160316.pkl_250.npy',
#  'gbdt_full_20160316.pkl_251.npy',
#  'gbdt_full_20160316.pkl_252.npy',
#  'gbdt_full_20160316.pkl_253.npy',
#  'gbdt_full_20160316.pkl_254.npy',
#  'gbdt_full_20160316.pkl_255.npy',
#  'gbdt_full_20160316.pkl_256.npy',
#  'gbdt_full_20160316.pkl_257.npy',
#  'gbdt_full_20160316.pkl_258.npy',
#  'gbdt_full_20160316.pkl_259.npy',
#  'gbdt_full_20160316.pkl_260.npy',
#  'gbdt_full_20160316.pkl_261.npy',
#  'gbdt_full_20160316.pkl_262.npy',
#  'gbdt_full_20160316.pkl_263.npy',
#  'gbdt_full_20160316.pkl_264.npy',
#  'gbdt_full_20160316.pkl_265.npy',
#  'gbdt_full_20160316.pkl_266.npy',
#  'gbdt_full_20160316.pkl_267.npy',
#  'gbdt_full_20160316.pkl_268.npy',
#  'gbdt_full_20160316.pkl_269.npy',
#  'gbdt_full_20160316.pkl_270.npy',
#  'gbdt_full_20160316.pkl_271.npy',
#  'gbdt_full_20160316.pkl_272.npy',
#  'gbdt_full_20160316.pkl_273.npy',
#  'gbdt_full_20160316.pkl_274.npy',
#  'gbdt_full_20160316.pkl_275.npy',
#  'gbdt_full_20160316.pkl_276.npy',
#  'gbdt_full_20160316.pkl_277.npy',
#  'gbdt_full_20160316.pkl_278.npy',
#  'gbdt_full_20160316.pkl_279.npy',
#  'gbdt_full_20160316.pkl_280.npy',
#  'gbdt_full_20160316.pkl_281.npy',
#  'gbdt_full_20160316.pkl_282.npy',
#  'gbdt_full_20160316.pkl_283.npy',
#  'gbdt_full_20160316.pkl_284.npy',
#  'gbdt_full_20160316.pkl_285.npy',
#  'gbdt_full_20160316.pkl_286.npy',
#  'gbdt_full_20160316.pkl_287.npy',
#  'gbdt_full_20160316.pkl_288.npy',
#  'gbdt_full_20160316.pkl_289.npy',
#  'gbdt_full_20160316.pkl_290.npy',
#  'gbdt_full_20160316.pkl_291.npy',
#  'gbdt_full_20160316.pkl_292.npy',
#  'gbdt_full_20160316.pkl_293.npy',
#  'gbdt_full_20160316.pkl_294.npy',
#  'gbdt_full_20160316.pkl_295.npy',
#  'gbdt_full_20160316.pkl_296.npy',
#  'gbdt_full_20160316.pkl_297.npy',
#  'gbdt_full_20160316.pkl_298.npy',
#  'gbdt_full_20160316.pkl_299.npy',
#  'gbdt_full_20160316.pkl_300.npy',
#  'gbdt_full_20160316.pkl_301.npy',
#  'gbdt_full_20160316.pkl_302.npy',
#  'gbdt_full_20160316.pkl_303.npy',
#  'gbdt_full_20160316.pkl_304.npy',
#  'gbdt_full_20160316.pkl_305.npy',
#  'gbdt_full_20160316.pkl_306.npy',
#  'gbdt_full_20160316.pkl_307.npy',
#  'gbdt_full_20160316.pkl_308.npy',
#  'gbdt_full_20160316.pkl_309.npy',
#  'gbdt_full_20160316.pkl_310.npy',
#  'gbdt_full_20160316.pkl_311.npy',
#  'gbdt_full_20160316.pkl_312.npy',
#  'gbdt_full_20160316.pkl_313.npy',
#  'gbdt_full_20160316.pkl_314.npy',
#  'gbdt_full_20160316.pkl_315.npy',
#  'gbdt_full_20160316.pkl_316.npy',
#  'gbdt_full_20160316.pkl_317.npy',
#  'gbdt_full_20160316.pkl_318.npy',
#  'gbdt_full_20160316.pkl_319.npy',
#  'gbdt_full_20160316.pkl_320.npy',
#  'gbdt_full_20160316.pkl_321.npy',
#  'gbdt_full_20160316.pkl_322.npy',
#  'gbdt_full_20160316.pkl_323.npy',
#  'gbdt_full_20160316.pkl_324.npy',
#  'gbdt_full_20160316.pkl_325.npy',
#  'gbdt_full_20160316.pkl_326.npy',
#  'gbdt_full_20160316.pkl_327.npy',
#  'gbdt_full_20160316.pkl_328.npy',
#  'gbdt_full_20160316.pkl_329.npy',
#  'gbdt_full_20160316.pkl_330.npy',
#  'gbdt_full_20160316.pkl_331.npy',
#  'gbdt_full_20160316.pkl_332.npy',
#  'gbdt_full_20160316.pkl_333.npy',
#  'gbdt_full_20160316.pkl_334.npy',
#  'gbdt_full_20160316.pkl_335.npy',
#  'gbdt_full_20160316.pkl_336.npy',
#  'gbdt_full_20160316.pkl_337.npy',
#  'gbdt_full_20160316.pkl_338.npy',
#  'gbdt_full_20160316.pkl_339.npy',
#  'gbdt_full_20160316.pkl_340.npy',
#  'gbdt_full_20160316.pkl_341.npy',
#  'gbdt_full_20160316.pkl_342.npy',
#  'gbdt_full_20160316.pkl_343.npy',
#  'gbdt_full_20160316.pkl_344.npy',
#  'gbdt_full_20160316.pkl_345.npy',
#  'gbdt_full_20160316.pkl_346.npy',
#  'gbdt_full_20160316.pkl_347.npy',
#  'gbdt_full_20160316.pkl_348.npy',
#  'gbdt_full_20160316.pkl_349.npy',
#  'gbdt_full_20160316.pkl_350.npy',
#  'gbdt_full_20160316.pkl_351.npy',
#  'gbdt_full_20160316.pkl_352.npy',
#  'gbdt_full_20160316.pkl_353.npy',
#  'gbdt_full_20160316.pkl_354.npy',
#  'gbdt_full_20160316.pkl_355.npy',
#  'gbdt_full_20160316.pkl_356.npy',
#  'gbdt_full_20160316.pkl_357.npy',
#  'gbdt_full_20160316.pkl_358.npy',
#  'gbdt_full_20160316.pkl_359.npy',
#  'gbdt_full_20160316.pkl_360.npy',
#  'gbdt_full_20160316.pkl_361.npy',
#  'gbdt_full_20160316.pkl_362.npy',
#  'gbdt_full_20160316.pkl_363.npy',
#  'gbdt_full_20160316.pkl_364.npy',
#  'gbdt_full_20160316.pkl_365.npy',
#  'gbdt_full_20160316.pkl_366.npy',
#  'gbdt_full_20160316.pkl_367.npy',
#  'gbdt_full_20160316.pkl_368.npy',
#  'gbdt_full_20160316.pkl_369.npy',
#  'gbdt_full_20160316.pkl_370.npy',
#  'gbdt_full_20160316.pkl_371.npy',
#  'gbdt_full_20160316.pkl_372.npy',
#  'gbdt_full_20160316.pkl_373.npy',
#  'gbdt_full_20160316.pkl_374.npy',
#  'gbdt_full_20160316.pkl_375.npy',
#  'gbdt_full_20160316.pkl_376.npy',
#  'gbdt_full_20160316.pkl_377.npy',
#  'gbdt_full_20160316.pkl_378.npy',
#  'gbdt_full_20160316.pkl_379.npy',
#  'gbdt_full_20160316.pkl_380.npy',
#  'gbdt_full_20160316.pkl_381.npy',
#  'gbdt_full_20160316.pkl_382.npy',
#  'gbdt_full_20160316.pkl_383.npy',
#  'gbdt_full_20160316.pkl_384.npy',
#  'gbdt_full_20160316.pkl_385.npy',
#  'gbdt_full_20160316.pkl_386.npy',
#  'gbdt_full_20160316.pkl_387.npy',
#  'gbdt_full_20160316.pkl_388.npy',
#  'gbdt_full_20160316.pkl_389.npy',
#  'gbdt_full_20160316.pkl_390.npy',
#  'gbdt_full_20160316.pkl_391.npy',
#  'gbdt_full_20160316.pkl_392.npy',
#  'gbdt_full_20160316.pkl_393.npy',
#  'gbdt_full_20160316.pkl_394.npy',
#  'gbdt_full_20160316.pkl_395.npy',
#  'gbdt_full_20160316.pkl_396.npy',
#  'gbdt_full_20160316.pkl_397.npy',
#  'gbdt_full_20160316.pkl_398.npy',
#  'gbdt_full_20160316.pkl_399.npy',
#  'gbdt_full_20160316.pkl_400.npy',
#  'gbdt_full_20160316.pkl_401.npy',
#  'gbdt_full_20160316.pkl_402.npy',
#  'gbdt_full_20160316.pkl_403.npy',
#  'gbdt_full_20160316.pkl_404.npy',
#  'gbdt_full_20160316.pkl_405.npy',
#  'gbdt_full_20160316.pkl_406.npy',
#  'gbdt_full_20160316.pkl_407.npy',
#  'gbdt_full_20160316.pkl_408.npy',
#  'gbdt_full_20160316.pkl_409.npy',
#  'gbdt_full_20160316.pkl_410.npy',
#  'gbdt_full_20160316.pkl_411.npy',
#  'gbdt_full_20160316.pkl_412.npy',
#  'gbdt_full_20160316.pkl_413.npy',
#  'gbdt_full_20160316.pkl_414.npy',
#  'gbdt_full_20160316.pkl_415.npy',
#  'gbdt_full_20160316.pkl_416.npy',
#  'gbdt_full_20160316.pkl_417.npy',
#  'gbdt_full_20160316.pkl_418.npy',
#  'gbdt_full_20160316.pkl_419.npy',
#  'gbdt_full_20160316.pkl_420.npy',
#  'gbdt_full_20160316.pkl_421.npy',
#  'gbdt_full_20160316.pkl_422.npy',
#  'gbdt_full_20160316.pkl_423.npy',
#  'gbdt_full_20160316.pkl_424.npy',
#  'gbdt_full_20160316.pkl_425.npy',
#  'gbdt_full_20160316.pkl_426.npy',
#  'gbdt_full_20160316.pkl_427.npy',
#  'gbdt_full_20160316.pkl_428.npy',
#  'gbdt_full_20160316.pkl_429.npy',
#  'gbdt_full_20160316.pkl_430.npy',
#  'gbdt_full_20160316.pkl_431.npy',
#  'gbdt_full_20160316.pkl_432.npy',
#  'gbdt_full_20160316.pkl_433.npy',
#  'gbdt_full_20160316.pkl_434.npy',
#  'gbdt_full_20160316.pkl_435.npy',
#  'gbdt_full_20160316.pkl_436.npy',
#  'gbdt_full_20160316.pkl_437.npy',
#  'gbdt_full_20160316.pkl_438.npy',
#  'gbdt_full_20160316.pkl_439.npy',
#  'gbdt_full_20160316.pkl_440.npy',
#  'gbdt_full_20160316.pkl_441.npy',
#  'gbdt_full_20160316.pkl_442.npy',
#  'gbdt_full_20160316.pkl_443.npy',
#  'gbdt_full_20160316.pkl_444.npy',
#  'gbdt_full_20160316.pkl_445.npy',
#  'gbdt_full_20160316.pkl_446.npy',
#  'gbdt_full_20160316.pkl_447.npy',
#  'gbdt_full_20160316.pkl_448.npy',
#  'gbdt_full_20160316.pkl_449.npy',
#  'gbdt_full_20160316.pkl_450.npy',
#  'gbdt_full_20160316.pkl_451.npy',
#  'gbdt_full_20160316.pkl_452.npy',
#  'gbdt_full_20160316.pkl_453.npy',
#  'gbdt_full_20160316.pkl_454.npy',
#  'gbdt_full_20160316.pkl_455.npy',
#  'gbdt_full_20160316.pkl_456.npy',
#  'gbdt_full_20160316.pkl_457.npy',
#  'gbdt_full_20160316.pkl_458.npy',
#  'gbdt_full_20160316.pkl_459.npy',
#  'gbdt_full_20160316.pkl_460.npy',
#  'gbdt_full_20160316.pkl_461.npy',
#  'gbdt_full_20160316.pkl_462.npy',
#  'gbdt_full_20160316.pkl_463.npy',
#  'gbdt_full_20160316.pkl_464.npy',
#  'gbdt_full_20160316.pkl_465.npy',
#  'gbdt_full_20160316.pkl_466.npy',
#  'gbdt_full_20160316.pkl_467.npy',
#  'gbdt_full_20160316.pkl_468.npy',
#  'gbdt_full_20160316.pkl_469.npy',
#  'gbdt_full_20160316.pkl_470.npy',
#  'gbdt_full_20160316.pkl_471.npy',
#  'gbdt_full_20160316.pkl_472.npy',
#  'gbdt_full_20160316.pkl_473.npy',
#  'gbdt_full_20160316.pkl_474.npy',
#  'gbdt_full_20160316.pkl_475.npy',
#  'gbdt_full_20160316.pkl_476.npy',
#  'gbdt_full_20160316.pkl_477.npy',
#  'gbdt_full_20160316.pkl_478.npy',
#  'gbdt_full_20160316.pkl_479.npy',
#  'gbdt_full_20160316.pkl_480.npy',
#  'gbdt_full_20160316.pkl_481.npy',
#  'gbdt_full_20160316.pkl_482.npy',
#  'gbdt_full_20160316.pkl_483.npy',
#  'gbdt_full_20160316.pkl_484.npy',
#  'gbdt_full_20160316.pkl_485.npy',
#  'gbdt_full_20160316.pkl_486.npy',
#  'gbdt_full_20160316.pkl_487.npy',
#  'gbdt_full_20160316.pkl_488.npy',
#  'gbdt_full_20160316.pkl_489.npy',
#  'gbdt_full_20160316.pkl_490.npy',
#  'gbdt_full_20160316.pkl_491.npy',
#  'gbdt_full_20160316.pkl_492.npy',
#  'gbdt_full_20160316.pkl_493.npy',
#  'gbdt_full_20160316.pkl_494.npy',
#  'gbdt_full_20160316.pkl_495.npy',
#  'gbdt_full_20160316.pkl_496.npy',
#  'gbdt_full_20160316.pkl_497.npy',
#  'gbdt_full_20160316.pkl_498.npy',
#  'gbdt_full_20160316.pkl_499.npy',
#  'gbdt_full_20160316.pkl_500.npy',
#  'gbdt_full_20160316.pkl_501.npy',
#  'gbdt_full_20160316.pkl_502.npy',
#  'gbdt_full_20160316.pkl_503.npy',
#  'gbdt_full_20160316.pkl_504.npy',
#  'gbdt_full_20160316.pkl_505.npy',
#  'gbdt_full_20160316.pkl_506.npy',
#  'gbdt_full_20160316.pkl_507.npy',
#  'gbdt_full_20160316.pkl_508.npy',
#  'gbdt_full_20160316.pkl_509.npy',
#  'gbdt_full_20160316.pkl_510.npy',
#  'gbdt_full_20160316.pkl_511.npy',
#  'gbdt_full_20160316.pkl_512.npy',
#  'gbdt_full_20160316.pkl_513.npy',
#  'gbdt_full_20160316.pkl_514.npy',
#  'gbdt_full_20160316.pkl_515.npy',
#  'gbdt_full_20160316.pkl_516.npy',
#  'gbdt_full_20160316.pkl_517.npy',
#  'gbdt_full_20160316.pkl_518.npy',
#  'gbdt_full_20160316.pkl_519.npy',
#  'gbdt_full_20160316.pkl_520.npy',
#  'gbdt_full_20160316.pkl_521.npy',
#  'gbdt_full_20160316.pkl_522.npy',
#  'gbdt_full_20160316.pkl_523.npy',
#  'gbdt_full_20160316.pkl_524.npy',
#  'gbdt_full_20160316.pkl_525.npy',
#  'gbdt_full_20160316.pkl_526.npy',
#  'gbdt_full_20160316.pkl_527.npy',
#  'gbdt_full_20160316.pkl_528.npy',
#  'gbdt_full_20160316.pkl_529.npy',
#  'gbdt_full_20160316.pkl_530.npy',
#  'gbdt_full_20160316.pkl_531.npy',
#  'gbdt_full_20160316.pkl_532.npy',
#  'gbdt_full_20160316.pkl_533.npy',
#  'gbdt_full_20160316.pkl_534.npy',
#  'gbdt_full_20160316.pkl_535.npy',
#  'gbdt_full_20160316.pkl_536.npy',
#  'gbdt_full_20160316.pkl_537.npy',
#  'gbdt_full_20160316.pkl_538.npy',
#  'gbdt_full_20160316.pkl_539.npy',
#  'gbdt_full_20160316.pkl_540.npy',
#  'gbdt_full_20160316.pkl_541.npy',
#  'gbdt_full_20160316.pkl_542.npy',
#  'gbdt_full_20160316.pkl_543.npy',
#  'gbdt_full_20160316.pkl_544.npy',
#  'gbdt_full_20160316.pkl_545.npy',
#  'gbdt_full_20160316.pkl_546.npy',
#  'gbdt_full_20160316.pkl_547.npy',
#  'gbdt_full_20160316.pkl_548.npy',
#  'gbdt_full_20160316.pkl_549.npy',
#  'gbdt_full_20160316.pkl_550.npy',
#  'gbdt_full_20160316.pkl_551.npy',
#  'gbdt_full_20160316.pkl_552.npy',
#  'gbdt_full_20160316.pkl_553.npy',
#  'gbdt_full_20160316.pkl_554.npy',
#  'gbdt_full_20160316.pkl_555.npy',
#  'gbdt_full_20160316.pkl_556.npy',
#  'gbdt_full_20160316.pkl_557.npy',
#  'gbdt_full_20160316.pkl_558.npy',
#  'gbdt_full_20160316.pkl_559.npy',
#  'gbdt_full_20160316.pkl_560.npy',
#  'gbdt_full_20160316.pkl_561.npy',
#  'gbdt_full_20160316.pkl_562.npy',
#  'gbdt_full_20160316.pkl_563.npy',
#  'gbdt_full_20160316.pkl_564.npy',
#  'gbdt_full_20160316.pkl_565.npy',
#  'gbdt_full_20160316.pkl_566.npy',
#  'gbdt_full_20160316.pkl_567.npy',
#  'gbdt_full_20160316.pkl_568.npy',
#  'gbdt_full_20160316.pkl_569.npy',
#  'gbdt_full_20160316.pkl_570.npy',
#  'gbdt_full_20160316.pkl_571.npy',
#  'gbdt_full_20160316.pkl_572.npy',
#  'gbdt_full_20160316.pkl_573.npy',
#  'gbdt_full_20160316.pkl_574.npy',
#  'gbdt_full_20160316.pkl_575.npy',
#  'gbdt_full_20160316.pkl_576.npy',
#  'gbdt_full_20160316.pkl_577.npy',
#  'gbdt_full_20160316.pkl_578.npy',
#  'gbdt_full_20160316.pkl_579.npy',
#  'gbdt_full_20160316.pkl_580.npy',
#  'gbdt_full_20160316.pkl_581.npy',
#  'gbdt_full_20160316.pkl_582.npy',
#  'gbdt_full_20160316.pkl_583.npy',
#  'gbdt_full_20160316.pkl_584.npy',
#  'gbdt_full_20160316.pkl_585.npy',
#  'gbdt_full_20160316.pkl_586.npy',
#  'gbdt_full_20160316.pkl_587.npy',
#  'gbdt_full_20160316.pkl_588.npy',
#  'gbdt_full_20160316.pkl_589.npy',
#  'gbdt_full_20160316.pkl_590.npy',
#  'gbdt_full_20160316.pkl_591.npy',
#  'gbdt_full_20160316.pkl_592.npy',
#  'gbdt_full_20160316.pkl_593.npy',
#  'gbdt_full_20160316.pkl_594.npy',
#  'gbdt_full_20160316.pkl_595.npy',
#  'gbdt_full_20160316.pkl_596.npy',
#  'gbdt_full_20160316.pkl_597.npy',
#  'gbdt_full_20160316.pkl_598.npy',
#  'gbdt_full_20160316.pkl_599.npy',
#  'gbdt_full_20160316.pkl_600.npy',
#  'gbdt_full_20160316.pkl_601.npy',
#  'gbdt_full_20160316.pkl_602.npy',
#  'gbdt_full_20160316.pkl_603.npy',
#  'gbdt_full_20160316.pkl_604.npy',
#  'gbdt_full_20160316.pkl_605.npy',
#  'gbdt_full_20160316.pkl_606.npy',
#  'gbdt_full_20160316.pkl_607.npy',
#  'gbdt_full_20160316.pkl_608.npy',
#  'gbdt_full_20160316.pkl_609.npy',
#  'gbdt_full_20160316.pkl_610.npy',
#  'gbdt_full_20160316.pkl_611.npy',
#  'gbdt_full_20160316.pkl_612.npy',
#  'gbdt_full_20160316.pkl_613.npy',
#  'gbdt_full_20160316.pkl_614.npy',
#  'gbdt_full_20160316.pkl_615.npy',
#  'gbdt_full_20160316.pkl_616.npy',
#  'gbdt_full_20160316.pkl_617.npy',
#  'gbdt_full_20160316.pkl_618.npy',
#  'gbdt_full_20160316.pkl_619.npy',
#  'gbdt_full_20160316.pkl_620.npy',
#  'gbdt_full_20160316.pkl_621.npy',
#  'gbdt_full_20160316.pkl_622.npy',
#  'gbdt_full_20160316.pkl_623.npy',
#  'gbdt_full_20160316.pkl_624.npy',
#  'gbdt_full_20160316.pkl_625.npy',
#  'gbdt_full_20160316.pkl_626.npy',
#  'gbdt_full_20160316.pkl_627.npy',
#  'gbdt_full_20160316.pkl_628.npy',
#  'gbdt_full_20160316.pkl_629.npy',
#  'gbdt_full_20160316.pkl_630.npy',
#  'gbdt_full_20160316.pkl_631.npy',
#  'gbdt_full_20160316.pkl_632.npy',
#  'gbdt_full_20160316.pkl_633.npy',
#  'gbdt_full_20160316.pkl_634.npy',
#  'gbdt_full_20160316.pkl_635.npy',
#  'gbdt_full_20160316.pkl_636.npy',
#  'gbdt_full_20160316.pkl_637.npy',
#  'gbdt_full_20160316.pkl_638.npy',
#  'gbdt_full_20160316.pkl_639.npy',
#  'gbdt_full_20160316.pkl_640.npy',
#  'gbdt_full_20160316.pkl_641.npy',
#  'gbdt_full_20160316.pkl_642.npy',
#  'gbdt_full_20160316.pkl_643.npy',
#  'gbdt_full_20160316.pkl_644.npy',
#  'gbdt_full_20160316.pkl_645.npy',
#  'gbdt_full_20160316.pkl_646.npy',
#  'gbdt_full_20160316.pkl_647.npy',
#  'gbdt_full_20160316.pkl_648.npy',
#  'gbdt_full_20160316.pkl_649.npy',
#  'gbdt_full_20160316.pkl_650.npy',
#  'gbdt_full_20160316.pkl_651.npy',
#  'gbdt_full_20160316.pkl_652.npy',
#  'gbdt_full_20160316.pkl_653.npy',
#  'gbdt_full_20160316.pkl_654.npy',
#  'gbdt_full_20160316.pkl_655.npy',
#  'gbdt_full_20160316.pkl_656.npy',
#  'gbdt_full_20160316.pkl_657.npy',
#  'gbdt_full_20160316.pkl_658.npy',
#  'gbdt_full_20160316.pkl_659.npy',
#  'gbdt_full_20160316.pkl_660.npy',
#  'gbdt_full_20160316.pkl_661.npy',
#  'gbdt_full_20160316.pkl_662.npy',
#  'gbdt_full_20160316.pkl_663.npy',
#  'gbdt_full_20160316.pkl_664.npy',
#  'gbdt_full_20160316.pkl_665.npy',
#  'gbdt_full_20160316.pkl_666.npy',
#  'gbdt_full_20160316.pkl_667.npy',
#  'gbdt_full_20160316.pkl_668.npy',
#  'gbdt_full_20160316.pkl_669.npy',
#  'gbdt_full_20160316.pkl_670.npy',
#  'gbdt_full_20160316.pkl_671.npy',
#  'gbdt_full_20160316.pkl_672.npy',
#  'gbdt_full_20160316.pkl_673.npy',
#  'gbdt_full_20160316.pkl_674.npy',
#  'gbdt_full_20160316.pkl_675.npy',
#  'gbdt_full_20160316.pkl_676.npy',
#  'gbdt_full_20160316.pkl_677.npy',
#  'gbdt_full_20160316.pkl_678.npy',
#  'gbdt_full_20160316.pkl_679.npy',
#  'gbdt_full_20160316.pkl_680.npy',
#  'gbdt_full_20160316.pkl_681.npy',
#  'gbdt_full_20160316.pkl_682.npy',
#  'gbdt_full_20160316.pkl_683.npy',
#  'gbdt_full_20160316.pkl_684.npy',
#  'gbdt_full_20160316.pkl_685.npy',
#  'gbdt_full_20160316.pkl_686.npy',
#  'gbdt_full_20160316.pkl_687.npy',
#  'gbdt_full_20160316.pkl_688.npy',
#  'gbdt_full_20160316.pkl_689.npy',
#  'gbdt_full_20160316.pkl_690.npy',
#  'gbdt_full_20160316.pkl_691.npy',
#  'gbdt_full_20160316.pkl_692.npy',
#  'gbdt_full_20160316.pkl_693.npy',
#  'gbdt_full_20160316.pkl_694.npy',
#  'gbdt_full_20160316.pkl_695.npy',
#  'gbdt_full_20160316.pkl_696.npy',
#  'gbdt_full_20160316.pkl_697.npy',
#  'gbdt_full_20160316.pkl_698.npy',
#  'gbdt_full_20160316.pkl_699.npy',
#  'gbdt_full_20160316.pkl_700.npy',
#  'gbdt_full_20160316.pkl_701.npy',
#  'gbdt_full_20160316.pkl_702.npy',
#  'gbdt_full_20160316.pkl_703.npy',
#  'gbdt_full_20160316.pkl_704.npy',
#  'gbdt_full_20160316.pkl_705.npy',
#  'gbdt_full_20160316.pkl_706.npy',
#  'gbdt_full_20160316.pkl_707.npy',
#  'gbdt_full_20160316.pkl_708.npy',
#  'gbdt_full_20160316.pkl_709.npy',
#  'gbdt_full_20160316.pkl_710.npy',
#  'gbdt_full_20160316.pkl_711.npy',
#  'gbdt_full_20160316.pkl_712.npy',
#  'gbdt_full_20160316.pkl_713.npy',
#  'gbdt_full_20160316.pkl_714.npy',
#  'gbdt_full_20160316.pkl_715.npy',
#  'gbdt_full_20160316.pkl_716.npy',
#  'gbdt_full_20160316.pkl_717.npy',
#  'gbdt_full_20160316.pkl_718.npy',
#  'gbdt_full_20160316.pkl_719.npy',
#  'gbdt_full_20160316.pkl_720.npy',
#  'gbdt_full_20160316.pkl_721.npy',
#  'gbdt_full_20160316.pkl_722.npy',
#  'gbdt_full_20160316.pkl_723.npy',
#  'gbdt_full_20160316.pkl_724.npy',
#  'gbdt_full_20160316.pkl_725.npy',
#  'gbdt_full_20160316.pkl_726.npy',
#  'gbdt_full_20160316.pkl_727.npy',
#  'gbdt_full_20160316.pkl_728.npy',
#  'gbdt_full_20160316.pkl_729.npy',
#  'gbdt_full_20160316.pkl_730.npy',
#  'gbdt_full_20160316.pkl_731.npy',
#  'gbdt_full_20160316.pkl_732.npy',
#  'gbdt_full_20160316.pkl_733.npy',
#  'gbdt_full_20160316.pkl_734.npy',
#  'gbdt_full_20160316.pkl_735.npy',
#  'gbdt_full_20160316.pkl_736.npy',
#  'gbdt_full_20160316.pkl_737.npy',
#  'gbdt_full_20160316.pkl_738.npy',
#  'gbdt_full_20160316.pkl_739.npy',
#  'gbdt_full_20160316.pkl_740.npy',
#  'gbdt_full_20160316.pkl_741.npy',
#  'gbdt_full_20160316.pkl_742.npy',
#  'gbdt_full_20160316.pkl_743.npy',
#  'gbdt_full_20160316.pkl_744.npy',
#  'gbdt_full_20160316.pkl_745.npy',
#  'gbdt_full_20160316.pkl_746.npy',
#  'gbdt_full_20160316.pkl_747.npy',
#  'gbdt_full_20160316.pkl_748.npy',
#  'gbdt_full_20160316.pkl_749.npy',
#  'gbdt_full_20160316.pkl_750.npy',
#  'gbdt_full_20160316.pkl_751.npy',
#  'gbdt_full_20160316.pkl_752.npy',
#  'gbdt_full_20160316.pkl_753.npy',
#  'gbdt_full_20160316.pkl_754.npy',
#  'gbdt_full_20160316.pkl_755.npy',
#  'gbdt_full_20160316.pkl_756.npy',
#  'gbdt_full_20160316.pkl_757.npy',
#  'gbdt_full_20160316.pkl_758.npy',
#  'gbdt_full_20160316.pkl_759.npy',
#  'gbdt_full_20160316.pkl_760.npy',
#  'gbdt_full_20160316.pkl_761.npy',
#  'gbdt_full_20160316.pkl_762.npy',
#  'gbdt_full_20160316.pkl_763.npy',
#  'gbdt_full_20160316.pkl_764.npy',
#  'gbdt_full_20160316.pkl_765.npy',
#  'gbdt_full_20160316.pkl_766.npy',
#  'gbdt_full_20160316.pkl_767.npy',
#  'gbdt_full_20160316.pkl_768.npy',
#  'gbdt_full_20160316.pkl_769.npy',
#  'gbdt_full_20160316.pkl_770.npy',
#  'gbdt_full_20160316.pkl_771.npy',
#  'gbdt_full_20160316.pkl_772.npy',
#  'gbdt_full_20160316.pkl_773.npy',
#  'gbdt_full_20160316.pkl_774.npy',
#  'gbdt_full_20160316.pkl_775.npy',
#  'gbdt_full_20160316.pkl_776.npy',
#  'gbdt_full_20160316.pkl_777.npy',
#  'gbdt_full_20160316.pkl_778.npy',
#  'gbdt_full_20160316.pkl_779.npy',
#  'gbdt_full_20160316.pkl_780.npy',
#  'gbdt_full_20160316.pkl_781.npy',
#  'gbdt_full_20160316.pkl_782.npy',
#  'gbdt_full_20160316.pkl_783.npy',
#  'gbdt_full_20160316.pkl_784.npy',
#  'gbdt_full_20160316.pkl_785.npy',
#  'gbdt_full_20160316.pkl_786.npy',
#  'gbdt_full_20160316.pkl_787.npy',
#  'gbdt_full_20160316.pkl_788.npy',
#  'gbdt_full_20160316.pkl_789.npy',
#  'gbdt_full_20160316.pkl_790.npy',
#  'gbdt_full_20160316.pkl_791.npy',
#  'gbdt_full_20160316.pkl_792.npy',
#  'gbdt_full_20160316.pkl_793.npy',
#  'gbdt_full_20160316.pkl_794.npy',
#  'gbdt_full_20160316.pkl_795.npy',
#  'gbdt_full_20160316.pkl_796.npy',
#  'gbdt_full_20160316.pkl_797.npy',
#  'gbdt_full_20160316.pkl_798.npy',
#  'gbdt_full_20160316.pkl_799.npy',
#  'gbdt_full_20160316.pkl_800.npy',
#  'gbdt_full_20160316.pkl_801.npy',
#  'gbdt_full_20160316.pkl_802.npy',
#  'gbdt_full_20160316.pkl_803.npy',
#  'gbdt_full_20160316.pkl_804.npy',
#  'gbdt_full_20160316.pkl_805.npy',
#  'gbdt_full_20160316.pkl_806.npy',
#  'gbdt_full_20160316.pkl_807.npy',
#  'gbdt_full_20160316.pkl_808.npy',
#  'gbdt_full_20160316.pkl_809.npy',
#  'gbdt_full_20160316.pkl_810.npy',
#  'gbdt_full_20160316.pkl_811.npy',
#  'gbdt_full_20160316.pkl_812.npy',
#  'gbdt_full_20160316.pkl_813.npy',
#  'gbdt_full_20160316.pkl_814.npy',
#  'gbdt_full_20160316.pkl_815.npy',
#  'gbdt_full_20160316.pkl_816.npy',
#  'gbdt_full_20160316.pkl_817.npy',
#  'gbdt_full_20160316.pkl_818.npy',
#  'gbdt_full_20160316.pkl_819.npy',
#  'gbdt_full_20160316.pkl_820.npy',
#  'gbdt_full_20160316.pkl_821.npy',
#  'gbdt_full_20160316.pkl_822.npy',
#  'gbdt_full_20160316.pkl_823.npy',
#  'gbdt_full_20160316.pkl_824.npy',
#  'gbdt_full_20160316.pkl_825.npy',
#  'gbdt_full_20160316.pkl_826.npy',
#  'gbdt_full_20160316.pkl_827.npy',
#  'gbdt_full_20160316.pkl_828.npy',
#  'gbdt_full_20160316.pkl_829.npy',
#  'gbdt_full_20160316.pkl_830.npy',
#  'gbdt_full_20160316.pkl_831.npy',
#  'gbdt_full_20160316.pkl_832.npy',
#  'gbdt_full_20160316.pkl_833.npy',
#  'gbdt_full_20160316.pkl_834.npy',
#  'gbdt_full_20160316.pkl_835.npy',
#  'gbdt_full_20160316.pkl_836.npy',
#  'gbdt_full_20160316.pkl_837.npy',
#  'gbdt_full_20160316.pkl_838.npy',
#  'gbdt_full_20160316.pkl_839.npy',
#  'gbdt_full_20160316.pkl_840.npy',
#  'gbdt_full_20160316.pkl_841.npy',
#  'gbdt_full_20160316.pkl_842.npy',
#  'gbdt_full_20160316.pkl_843.npy',
#  'gbdt_full_20160316.pkl_844.npy',
#  'gbdt_full_20160316.pkl_845.npy',
#  'gbdt_full_20160316.pkl_846.npy',
#  'gbdt_full_20160316.pkl_847.npy',
#  'gbdt_full_20160316.pkl_848.npy',
#  'gbdt_full_20160316.pkl_849.npy',
#  'gbdt_full_20160316.pkl_850.npy',
#  'gbdt_full_20160316.pkl_851.npy',
#  'gbdt_full_20160316.pkl_852.npy',
#  'gbdt_full_20160316.pkl_853.npy',
#  'gbdt_full_20160316.pkl_854.npy',
#  'gbdt_full_20160316.pkl_855.npy',
#  'gbdt_full_20160316.pkl_856.npy',
#  'gbdt_full_20160316.pkl_857.npy',
#  'gbdt_full_20160316.pkl_858.npy',
#  'gbdt_full_20160316.pkl_859.npy',
#  'gbdt_full_20160316.pkl_860.npy',
#  'gbdt_full_20160316.pkl_861.npy',
#  'gbdt_full_20160316.pkl_862.npy',
#  'gbdt_full_20160316.pkl_863.npy',
#  'gbdt_full_20160316.pkl_864.npy',
#  'gbdt_full_20160316.pkl_865.npy',
#  'gbdt_full_20160316.pkl_866.npy',
#  'gbdt_full_20160316.pkl_867.npy',
#  'gbdt_full_20160316.pkl_868.npy',
#  'gbdt_full_20160316.pkl_869.npy',
#  'gbdt_full_20160316.pkl_870.npy',
#  'gbdt_full_20160316.pkl_871.npy',
#  'gbdt_full_20160316.pkl_872.npy',
#  'gbdt_full_20160316.pkl_873.npy',
#  'gbdt_full_20160316.pkl_874.npy',
#  'gbdt_full_20160316.pkl_875.npy',
#  'gbdt_full_20160316.pkl_876.npy',
#  'gbdt_full_20160316.pkl_877.npy',
#  'gbdt_full_20160316.pkl_878.npy',
#  'gbdt_full_20160316.pkl_879.npy',
#  'gbdt_full_20160316.pkl_880.npy',
#  'gbdt_full_20160316.pkl_881.npy',
#  'gbdt_full_20160316.pkl_882.npy',
#  'gbdt_full_20160316.pkl_883.npy',
#  'gbdt_full_20160316.pkl_884.npy',
#  'gbdt_full_20160316.pkl_885.npy',
#  'gbdt_full_20160316.pkl_886.npy',
#  'gbdt_full_20160316.pkl_887.npy',
#  'gbdt_full_20160316.pkl_888.npy',
#  'gbdt_full_20160316.pkl_889.npy',
#  'gbdt_full_20160316.pkl_890.npy',
#  'gbdt_full_20160316.pkl_891.npy',
#  'gbdt_full_20160316.pkl_892.npy',
#  'gbdt_full_20160316.pkl_893.npy',
#  'gbdt_full_20160316.pkl_894.npy',
#  'gbdt_full_20160316.pkl_895.npy',
#  'gbdt_full_20160316.pkl_896.npy',
#  'gbdt_full_20160316.pkl_897.npy',
#  'gbdt_full_20160316.pkl_898.npy',
#  'gbdt_full_20160316.pkl_899.npy',
#  'gbdt_full_20160316.pkl_900.npy',
#  'gbdt_full_20160316.pkl_901.npy',
#  'gbdt_full_20160316.pkl_902.npy',
#  'gbdt_full_20160316.pkl_903.npy',
#  'gbdt_full_20160316.pkl_904.npy',
#  'gbdt_full_20160316.pkl_905.npy',
#  'gbdt_full_20160316.pkl_906.npy',
#  'gbdt_full_20160316.pkl_907.npy',
#  'gbdt_full_20160316.pkl_908.npy',
#  'gbdt_full_20160316.pkl_909.npy',
#  'gbdt_full_20160316.pkl_910.npy',
#  'gbdt_full_20160316.pkl_911.npy',
#  'gbdt_full_20160316.pkl_912.npy',
#  'gbdt_full_20160316.pkl_913.npy',
#  'gbdt_full_20160316.pkl_914.npy',
#  'gbdt_full_20160316.pkl_915.npy',
#  'gbdt_full_20160316.pkl_916.npy',
#  'gbdt_full_20160316.pkl_917.npy',
#  'gbdt_full_20160316.pkl_918.npy',
#  'gbdt_full_20160316.pkl_919.npy',
#  'gbdt_full_20160316.pkl_920.npy',
#  'gbdt_full_20160316.pkl_921.npy',
#  'gbdt_full_20160316.pkl_922.npy',
#  'gbdt_full_20160316.pkl_923.npy',
#  'gbdt_full_20160316.pkl_924.npy',
#  'gbdt_full_20160316.pkl_925.npy',
#  'gbdt_full_20160316.pkl_926.npy',
#  'gbdt_full_20160316.pkl_927.npy',
#  'gbdt_full_20160316.pkl_928.npy',
#  'gbdt_full_20160316.pkl_929.npy',
#  'gbdt_full_20160316.pkl_930.npy',
#  'gbdt_full_20160316.pkl_931.npy',
#  'gbdt_full_20160316.pkl_932.npy',
#  'gbdt_full_20160316.pkl_933.npy',
#  'gbdt_full_20160316.pkl_934.npy',
#  'gbdt_full_20160316.pkl_935.npy',
#  'gbdt_full_20160316.pkl_936.npy',
#  'gbdt_full_20160316.pkl_937.npy',
#  'gbdt_full_20160316.pkl_938.npy',
#  'gbdt_full_20160316.pkl_939.npy',
#  'gbdt_full_20160316.pkl_940.npy',
#  'gbdt_full_20160316.pkl_941.npy',
#  'gbdt_full_20160316.pkl_942.npy',
#  'gbdt_full_20160316.pkl_943.npy',
#  'gbdt_full_20160316.pkl_944.npy',
#  'gbdt_full_20160316.pkl_945.npy',
#  'gbdt_full_20160316.pkl_946.npy',
#  'gbdt_full_20160316.pkl_947.npy',
#  'gbdt_full_20160316.pkl_948.npy',
#  'gbdt_full_20160316.pkl_949.npy',
#  'gbdt_full_20160316.pkl_950.npy',
#  'gbdt_full_20160316.pkl_951.npy',
#  'gbdt_full_20160316.pkl_952.npy',
#  'gbdt_full_20160316.pkl_953.npy',
#  'gbdt_full_20160316.pkl_954.npy',
#  'gbdt_full_20160316.pkl_955.npy',
#  'gbdt_full_20160316.pkl_956.npy',
#  'gbdt_full_20160316.pkl_957.npy',
#  'gbdt_full_20160316.pkl_958.npy',
#  'gbdt_full_20160316.pkl_959.npy',
#  'gbdt_full_20160316.pkl_960.npy',
#  'gbdt_full_20160316.pkl_961.npy',
#  'gbdt_full_20160316.pkl_962.npy',
#  'gbdt_full_20160316.pkl_963.npy',
#  'gbdt_full_20160316.pkl_964.npy',
#  'gbdt_full_20160316.pkl_965.npy',
#  'gbdt_full_20160316.pkl_966.npy',
#  'gbdt_full_20160316.pkl_967.npy',
#  'gbdt_full_20160316.pkl_968.npy',
#  'gbdt_full_20160316.pkl_969.npy',
#  'gbdt_full_20160316.pkl_970.npy',
#  'gbdt_full_20160316.pkl_971.npy',
#  'gbdt_full_20160316.pkl_972.npy',
#  'gbdt_full_20160316.pkl_973.npy',
#  'gbdt_full_20160316.pkl_974.npy',
#  'gbdt_full_20160316.pkl_975.npy',
#  'gbdt_full_20160316.pkl_976.npy',
#  'gbdt_full_20160316.pkl_977.npy',
#  'gbdt_full_20160316.pkl_978.npy',
#  'gbdt_full_20160316.pkl_979.npy',
#  'gbdt_full_20160316.pkl_980.npy',
#  'gbdt_full_20160316.pkl_981.npy',
#  'gbdt_full_20160316.pkl_982.npy',
#  'gbdt_full_20160316.pkl_983.npy',
#  'gbdt_full_20160316.pkl_984.npy',
#  'gbdt_full_20160316.pkl_985.npy',
#  'gbdt_full_20160316.pkl_986.npy',
#  'gbdt_full_20160316.pkl_987.npy',
#  'gbdt_full_20160316.pkl_988.npy',
#  'gbdt_full_20160316.pkl_989.npy',
#  'gbdt_full_20160316.pkl_990.npy',
#  'gbdt_full_20160316.pkl_991.npy',
#  'gbdt_full_20160316.pkl_992.npy',
#  'gbdt_full_20160316.pkl_993.npy',
#  'gbdt_full_20160316.pkl_994.npy',
#  'gbdt_full_20160316.pkl_995.npy',
#  'gbdt_full_20160316.pkl_996.npy',
#  'gbdt_full_20160316.pkl_997.npy',
#  'gbdt_full_20160316.pkl_998.npy',
#  'gbdt_full_20160316.pkl_999.npy',
#  ...]

# %%
figsize(12, 4)
compare_train_test(est, X_train, y_train, X_test, y_test)

# %%
figsize(6, 4)
def plot_ROC(est, X_test, y_test, X_train=None, y_train=None) : 
    from sklearn.metrics import auc
    est_decisions = est.predict_proba(X_test)[:, 1]
    est_fpr, est_tpr, thresholds = roc_curve(y_test, est_decisions)
    roc_auc = auc(est_fpr, est_tpr)
    
    plt.plot(est_fpr, est_tpr, lw=1, label = 'Test (area = %0.4f)'%(roc_auc))
    if X_train!=None and y_train!=None :
        est_decisions_train = est.predict_proba(X_train)[:, 1]
        est_fpr_train, est_tpr_train, _ = roc_curve(y_train, est_decisions_train)
        roc_auc_train = auc(est_fpr_train, est_tpr_train)
        plt.plot(est_fpr_train, est_tpr_train, lw=1, label = 'Train (area = %0.4f)'%(roc_auc_train))
    #plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Luck')
    plt.plot(0.127, 0.657, lw=1,marker = 'x', label='VBS cuts', color = 'black')

    plt.xlim([-0.05, .4])
    plt.ylim([0.4, 1.05])
    plt.xlabel('background efficiency')
    plt.ylabel('signal efficiency')
    plt.legend(loc="best", numpoints = 1)
    plt.grid()
    plt.show()
    
plot_ROC(est, X_test, y_test, X_train, y_train)
# Out:
# /grid_mnt/opt__exp_soft/cms/jupyter/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.

# %%
from math import log
def get_significance(tpr, fpr, s_fid_s, s_fid_b) :
    N_s = tpr*s_fid_s
    N_b = fpr*s_fid_b
    
    lnQ= -N_s + (N_s + N_b) * np.log(1 + N_s/N_b)
    s = lnQ**0.5   
     
    #denom = num + fpr*s_fid_b
    #denom = denom**0.5
    
    return s

# %%
s_fid_s = 0.1986
s_fid_b = 2.602

luminosity = 30.

# %%
    figsize(6, 4)
    significance = get_significance(est_tpr[100:-10], est_fpr[100:-10], s_fid_s, s_fid_b)
    significance[significance > 5] = 0
    plt.plot(est_tpr[100:-10], significance, alpha=0.5, color = 'red', label='significance')
    plt.ylabel('significance at 1 fb-1')
    plt.xlabel('signal efficiency')
    #plt.title('Receiver operating characteristic')
    #plt.legend(loc="best")
    plt.legend().set_visible(False)
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
    #plt.legend(numpoints=1)
    plt.grid()
    plt.show()
    significance_WP = np.max(significance)
    WP = np.argmax(significance)
    BDT_WP = thresholds[WP]
    print 'Maximum of S/(S+B)**0.5 is at : ', significance_WP

    print 'Signal eff ', est_tpr[WP]
    print 'Background eff ', est_fpr[WP]
    
    exp_sig_at_30 = luminosity*s_fid_s*est_tpr[WP]
    exp_bkg_at_30 = luminosity*s_fid_b*est_fpr[WP]
    
    print 'Expected signal events at 30fb-1 ', exp_sig_at_30
    print 'Expected background events at 30fb-1 ', exp_bkg_at_30    
    print 'BDT cut value ', BDT_WP
# Out:
# Maximum of S/(S+B)**0.5 is at :  0.264801614245
# Signal eff  0.353278445927
# Background eff  0.00690143165935
# Expected signal events at 30fb-1  2.10483298084
# Expected background events at 30fb-1  0.538725755329
# BDT cut value  0.944326344505

# %%
    lum = np.linspace(0, 100, 100)
    s_fid_s = 0.2115230295 #0.1986
    s_fid_b = 2.66579147967 #2.602
    plt.plot(lum, lum**0.5 * significance_WP, alpha=0.5, color = 'red', label='significance')
#plt.locator_params(nbins=10)
#plt.locator_params(axis='y',nbins=20)
#plt.plot(gbdt_fpr, gbdt_tpr, lw=1, label='GBDT')
#plt.xlim([-0.0, 0.45])
#plt.ylim([-0.05, 1.05])
    plt.ylabel('S/S+B')
    #plt.title('Receiver operating characteristic')
    #plt.legend(loc="best")
    plt.legend().set_visible(False)
    plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
    #plt.legend(numpoints=1)
    plt.grid()
    plt.show()

# %%
pass_bkg = est_decisions[y_test < 0.5] > BDT_WP
pass_sig = est_decisions[y_test > 0.5] > BDT_WP

X_test_bkg = X_test[y_test < 0.5]
X_test_sig = X_test[y_test > 0.5]

pass_bkg_weight = exp_bkg_at_30 / sum(pass_bkg) * np.ones(np.shape(X_test_bkg[pass_bkg,0]))
pass_sig_weight = exp_sig_at_30  / sum(pass_sig) * np.ones(np.shape(X_test_sig[pass_sig,0]))

bkg_weight = luminosity*s_fid_b / sum(np.ones(np.shape(X_test_bkg[:,0]))) * np.ones(np.shape(X_test_bkg[:,0]))
sig_weight = luminosity*s_fid_s  / sum(np.ones(np.shape(X_test_sig[:,0]))) * np.ones(np.shape(X_test_sig[:,0]))

print 'sum weights ', sum(bkg_weight)
print 'sum weights pass ', sum(pass_bkg_weight)

print 'sum weights ', sum(sig_weight)
print 'sum weights pass ', sum(pass_sig_weight)
# Out:
# sum weights  79.9737443908
# sum weights pass  0.538725755329
# sum weights  6.34569088507
# sum weights pass  2.10483298084

# %%
BDT_bkg = est_decisions[y_test < 0.5]
BDT_sig = est_decisions[y_test > 0.5]

min_BDT = 0.5
max_BDT = 1
bins_BDT = 10


figsize(12,4)
plt.subplot(121)
n, _, _ = plt.hist([BDT_bkg, BDT_sig], 
         bins=bins_BDT, range=(min_BDT, max_BDT) , weights = [bkg_weight, sig_weight]
         , lw=1, alpha=0.5, color = ['red', 'orange'], label=['background', 'signal'], stacked = True)
plt.xlabel('BDT score')
plt.ylabel('Events @ 30 fb-1')
plt.legend(loc="best")
plt.grid()
ax =plt.subplot(122)
ax.set_yscale("log", nonposy='clip')
plt.hist([BDT_bkg, BDT_sig], 
         bins=bins_BDT 
         , lw=1, alpha=0.5, color = ['red', 'orange'], label=['background', 'signal'])
plt.xlabel('BDT score')
plt.ylabel('Number of MC events')
plt.legend(loc="best")
plt.grid()

print 'signal overflow: ', sum(BDT_sig > max_BDT), 'in event counts at 30fb ', sum(sig_weight*(BDT_sig > max_BDT))
print 'background overflow: ', sum(BDT_bkg > max_BDT), 'in event counts at 30fb ', sum(bkg_weight*(BDT_bkg > max_BDT))
# Out:
# signal overflow:  0 in event counts at 30fb  0.0
# background overflow:  0 in event counts at 30fb  0.0

# %%
figsize(8,4)
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt

N_b = n[0]
N_s = n[1] - n[0] # second histo is stack!

weight = np.log(1 + N_s / N_b)
second_term = (N_s + N_b)* weight


from __future__ import division
middle = (max_BDT - min_BDT) / bins_BDT / 2
sigma = -sum(N_s) + sum(second_term)
sigma = (2*sigma)**0.5
print 'sigma: ', sigma



host = host_subplot(111, axes_class=AA.Axes)
plt.subplots_adjust(right=0.75)

par1 = host.twinx()
par2 = host.twinx()

offset = 60
new_fixed_axis = par2.get_grid_helper().new_fixed_axis
par2.axis["right"] = new_fixed_axis(loc="right",
                                    axes=par2,
                                    offset=(offset, 0))

par2.axis["right"].toggle(all=True)

host.set_xlim(min_BDT, max_BDT)
host.set_ylim(0, 30)

host.set_xlabel("BDT score")
host.set_ylabel(r'Events at 30 fb$^{-1}$')
par1.set_ylabel(r'$log(1 + N_s^i / N_b^i)$')
par2.set_ylabel(r'$(N_s^i + N_b^i) * log(1 + N_s^i / N_b^i)$')

p1 = host.hist([BDT_bkg, BDT_sig], 
         bins=bins_BDT, range=(min_BDT, max_BDT) , weights = [bkg_weight, sig_weight]
         , lw=1, alpha=0.5, color = ['red', 'orange'], label=['background', 'signal'], stacked = True)
p2, = par1.plot(np.linspace(min_BDT + middle, max_BDT + middle , bins_BDT, endpoint=False), weight , '-ro')
p3, = par2.plot(np.linspace(min_BDT + middle, max_BDT + middle , bins_BDT, endpoint=False), second_term , '-bo')


par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right"].label.set_color(p3.get_color())
# Out:
# sigma:  2.40335660052

# %%
n, bins, _ = plt.hist([BDT_bkg, BDT_sig], 
             bins=bins_BDT, range=(min_BDT, max_BDT)
             , lw=1, alpha=0.5, color = ['red', 'orange'], label=['background', 'signal'])
print n

sig = n[1]
bkg = n[0]
print sig

print sig / (sig + bkg)
# Out:
# [array([  66387.,  111750.,   78718.,   53977.,   38849.,   29254.,
#          23326.,   18545.,   15394.,   12924.,   10994.,    9172.,
#           8127.,    7223.,    6303.,    5910.,    5537.,    5360.,
#           5040.,    3045.]), array([   2180.,    8924.,   11204.,   11812.,   11612.,   11450.,
#          11306.,   11467.,   11436.,   11485.,   12138.,   12370.,
#          12950.,   14332.,   16194.,   18901.,   24231.,   34285.,
#          60926.,  153684.])]
# [   2180.    8924.   11204.   11812.   11612.   11450.   11306.   11467.
#    11436.   11485.   12138.   12370.   12950.   14332.   16194.   18901.
#    24231.   34285.   60926.  153684.]
# [ 0.03179372  0.07395131  0.12459687  0.17954369  0.23011831  0.28129914
#   0.32646108  0.3820805   0.42623928  0.47052317  0.52472765  0.57422709
#   0.61441382  0.66490373  0.71982931  0.7617992   0.81399489  0.8648001
#   0.923597    0.98057156]

# %%
plots = [(r'$m_{jj}$ [GeV]', 3 , [0, 3000]),
         (r'$\Delta\eta_{jj}$', 20, [-10, 10]),
         (r'$m_{4l}$', 20, [0, 2000]),
         (r'$\eta^{*}_{Z_{1}}$', 10, [-5, 5]),
         (r'$\eta^{*}_{Z_{2}}$', 10, [-5, 5]),
         (r'$\Delta\phi(Z_{1}, Z_{2})$', 10, [-5,5]),
         (r'$\eta_{j_{1}}\times\eta_{j_{2}}$', 20, [-10, 10]),
         (r'$\cos{\theta^*}$', 22, [-1.1, 1.1]),
         (r'$\Phi$', 20, [-3.3, 3.3]),
         (r'$\cos \theta_1$', 22, [-1.1, 1.1]),
         (r'$\cos \theta_2$', 22, [-1.1, 1.1]),
         (r'$\Phi_1$', 20, [-3.3, 3.3]),
         (r'$VBF \cos{\theta^*}$', 22, [-1.1, 1.1]),
         (r'$VBF \cos \theta_1$', 22, [-1.1, 1.1]),
         (r'$VBF \cos \theta_2$', 22, [-1.1, 1.1]),
         (r'$VBF \Phi$', 20, [-3.3, 3.3]),
         (r'$VBF \Phi_1$', 20, [-3.3, 3.3]),
         (r'$q_{V1}$ [GeV]', 30 , [0, 3000]),
         (r'$q_{V2}$ [GeV]', 30 , [0, 3000]),         
        ]



def plot_BDT_selection(plot_index) :
    figsize(18, 4)
    p = plots[plot_index]
    plt.subplot(131)
    plt.hist(X_test_sig[:,plot_index]        , bins=p[1], range=p[2], weights = sig_weight, lw=1, alpha=0.5, color = 'navy', label='all')
    plt.hist(X_test_sig[pass_sig, plot_index], bins=p[1], range=p[2] , weights = pass_sig_weight, lw=1, alpha=0.5, color = 'blue', label='pass BDT')
    #plt.hist(red_sig[:,0], bins=p[1], range=p[2], normed=1, lw=1, alpha=0.5, color = 'blue', label='sig')
    plt.xlabel(p[0])
    plt.ylabel('Events @ 30 fb-1')
    plt.legend(loc="best")
    plt.title("Signal")
    plt.grid()


    plt.subplot(132)
    plt.hist(X_test_bkg[:,plot_index]        , bins=p[1], range=p[2], weights = bkg_weight, lw=1, alpha=0.5, color = 'navy', label='all')
    plt.hist(X_test_bkg[pass_bkg, plot_index], bins=p[1], range=p[2] , weights = pass_bkg_weight, lw=1, alpha=0.5, color = 'blue', label='pass BDT')
    #plt.hist(red_sig[:,0], bins=p[1], range=p[2], normed=1, lw=1, alpha=0.5, color = 'blue', label='sig')
    plt.xlabel(p[0])
    plt.ylabel('Events @ 30 fb-1')
    plt.title("Background")
    plt.legend(loc="best")
    plt.yscale('log', nonposy='clip')
    plt.grid()


    plt.subplot(133)
    n, _, _ = plt.hist([X_test_bkg[pass_bkg, plot_index], X_test_sig[pass_sig, plot_index]], 
             bins=p[1], range=p[2] , weights = [pass_bkg_weight, pass_sig_weight]
             , lw=1, alpha=0.5, color = ['red', 'orange'], label=['background', 'signal'], stacked = True)

    plt.xlabel(p[0])
    plt.ylabel('Events @ 30 fb-1')
    plt.title("BDT selection")
    plt.legend(loc="best")
    plt.grid()
    
    N_b = n[0]
    N_s = n[1] - n[0] # second histo is stack!

    print 'sigma: ', get_ln_significance(N_s, N_b)

    plt.show()

# %%
import pickle


#pickle.dump(gbdt, open( "gbdt_best.pkl", "wb" ))
def get_ln_significance(N_s, N_b) :
    weight = np.log(1 + N_s / N_b)
    second_term = (N_s + N_b)* weight
    sigma = -sum(N_s) + sum(second_term)
    sigma = (2*sigma)**0.5
    return sigma

# %%
plot_BDT_selection(0) # mjj
# Out:
# sigma:  1.97547052267

# %%
plot_BDT_selection(2) # m4l
# Out:
# sigma:  nan
