# %%
import sys

sys.path.append('/Users/pigard/CMS/ZZ_analysis')

import ROOT
from plot_tools import *
prefix = '/Users/pigard/CMS/ZZ_analysis/'
# Out:
# /Users/pigard/CMS/ZZ_analysis/plot_tools.py:481: SyntaxWarning: import * only allowed at module level
#   def get_y_title(histo, draw_options) :
# Welcome to ROOTaaS 6.05/02

# %% [markdown]
# # Fraction of 4 electron events with x electrons in EB

# %%
save_plot([ {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_0EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '0 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_1EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '1 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_2EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '2 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_3EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '3 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_4EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kYellow, 'legend_title' : '4 EB'}}
          ], 
          draw_options = {'y_title' : 'fraction per m_{ZZ} bin', 'draw_option' : 'nostack', 'per_bin_norm' : True})
# Out:
# [<ROOT.TH1F object ("Acc_0EB__gen_ZZ_mass__4e_copy0.85344425282") at 0x7f83c42f1c10>, <ROOT.TH1F object ("Acc_1EB__gen_ZZ_mass__4e_copy0.494612665229") at 0x7f83c5d9d4b0>, <ROOT.TH1F object ("Acc_2EB__gen_ZZ_mass__4e_copy0.328783340401") at 0x7f83c5dbe400>, <ROOT.TH1F object ("Acc_3EB__gen_ZZ_mass__4e_copy0.0267285186159") at 0x7f83c5dbf240>, <ROOT.TH1F object ("Acc_4EB__gen_ZZ_mass__4e_copy0.813614690126") at 0x7f83c5dc0090>]
# nostack

# %% [markdown]
# # Fraction of 2 electron events with x electrons in EB

# %%
save_plot([ {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_0EB__gen_ZZ_mass__2e2m'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '0 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_1EB__gen_ZZ_mass__2e2m'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '1 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5.root', 'raw/Acc_2EB__gen_ZZ_mass__2e2m'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '2 EB'}},
          ], 
          draw_options = {'y_title' : 'fraction per m_{ZZ} bin', 'draw_option' : 'nostack', 'per_bin_norm' : True})
# Out:
# [<ROOT.TH1F object ("Acc_0EB__gen_ZZ_mass__2e2m_copy0.834774869417") at 0x7f83c5d95b80>, <ROOT.TH1F object ("Acc_1EB__gen_ZZ_mass__2e2m_copy0.719550862132") at 0x7f83c5dba230>, <ROOT.TH1F object ("Acc_2EB__gen_ZZ_mass__2e2m_copy0.666420826621") at 0x7f83c42b6910>]
# nostack

# %%
def plot_efficiencies_per_final_state(file_name, plot_name, y_title, extra_options = {}) :
    options = {'draw_option' : 'APL'}
    options.update(extra_options)
    save_plot([
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__all'),
           'draw_options' : {'legend_title' : 'sum', 'color' : ROOT.kBlack, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__4m'),
           'draw_options' : {'legend_title' : '4#mu', 'color' : ROOT.kRed, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__2e2m'),
           'draw_options' : {'legend_title' : '2#mu2e', 'color' : ROOT.kBlue, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__4e'),
           'draw_options' : {'legend_title' : '4e', 'color' : ROOT.kGreen, 'MarkerStyle': 27}},
            ],
               draw_options = options)
    
def plot_selection_step_efficiencies(file_name, final_state, y_title) :
    save_plot([
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'RECO', 'color' : ROOT.kBlack, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isID_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ID', 'color' : ROOT.kBlue, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isISO_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ISO', 'color' : ROOT.kRed, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isISO_isID_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ID and ISO', 'color' : ROOT.kGreen, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isISO_isID_isSIP_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ID and ISO and SIP', 'color' : ROOT.kYellow, 'MarkerStyle': 27}},
              ],
               draw_options = {'draw_option' : 'APL', 'legend_position' : (.60,.15,.89,.35)})

# %% [markdown]
# # ZZjj BLS selection efficiency with respect to GEN level:

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_74X_v2_v5.root', 'gen_CJLST_and_BLS_eff_gen_ZZ_mass', 'selection efficiency from GEN')

# %% [markdown]
# # ZZjj VBS selection efficiency with respect to GEN level:

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_74X_v2_v5.root', 'gen_CJLST_and_VBS_eff_gen_ZZ_mass', 'VBS selection efficiency from GEN')
# Out:
# is MultiGraph
# APL

# %% [markdown]
# # ZZjj BLS selection efficiency with respect to the lepton acceptance:
#     - jet acceptance is not included but will be added

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_74X_v2_v5.root', 'Acc_CJLST_and_BLS_eff_gen_ZZ_mass', 
                                  'BLS selection efficiency in accpetance', {'legend_position' : (.60,.15,.89,.35)})

# %% [markdown]
# # ZZjj VBS selection efficiency with respect to the lepton acceptance:
#     - jet acceptance is not included but will be added

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_74X_v5.root', 'Acc_CJLST_and_VBS_eff_gen_ZZ_mass', 'VBS selection efficiency in accpetance')
# Out:
# is MultiGraph
# APL

# %% [markdown]
# # ZZ selection efficiency from CJLST with respect to GEN level:
#     - this does not include any jet selection

# %%
plot_efficiencies('out_zzjj_ewk_74X_v2_v5.root', 'gen_CJLST_eff_gen_ZZ_mass', 'ZZ selection efficiency for GEN')
# Out:
# is MultiGraph
# APL

# %% [markdown]
# # ZZ selection efficiency from CJLST with respect to lepton acceptance:

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_74X_v2_v5.root', 'Acc_CJLST_eff_gen_ZZ_mass', 
                  'ZZ selection efficiency for GEN', {'legend_position' : (.60,.15,.89,.35)})

# %%
# ZZ selection efficiency from loose lepton CJLST with respect to lepton acceptance:
plot_efficiencies_per_final_state('out_zzjj_ewk_74X_v2_v5.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass', 
                                  'ZZ selection efficiency for GEN', {'legend_position' : (.60,.15,.89,.35)})

# %% [markdown]
# # Efficiency of ZZjj BLS selection on top of CJLST ZZ slection in lepton acceptance (effect of jj selection)

# %%
def plot_efficiencies_CJLST_to_BLS(file_name, plot_name, y_title, extra_options = {}) :
    options = {'draw_option' : 'APL'}
    options.update(extra_options)
    save_plot([
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_CJLST_eff_gen_ZZ_mass__all'),
           'draw_options' : {'legend_title' : 'ZZ selection', 'color' : ROOT.kBlack, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_CJLST_and_BLS_eff_gen_ZZ_mass__all'),
           'draw_options' : {'legend_title' : 'BLS selection', 'color' : ROOT.kRed, 'MarkerStyle': 27}},

            ],
               draw_options = options)
plot_efficiencies_CJLST_to_BLS('out_zzjj_ewk_74X_v2_v5.root', '', '')

# %%
def check_eff(file_name1,file_name2, plot_name, y_title, final_state) :
    options = {'draw_option' : 'APL', 'legend_position' : (.40,.15,.89,.35)}
    save_plot([
          {'p' : get_eff(prefix + file_name1, 'raw/Acc_lep_loose_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'regular CLJST', 'color' : ROOT.kBlack, 'MarkerStyle': 27}},
          {'p' : get_eff(prefix + file_name2, 'raw/Acc_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'loose CJLST + ID + ISO + SIP', 'color' : ROOT.kRed, 'MarkerStyle': 27}},
               ],
            draw_options = options)

# %%
check_eff('out_zzjj_ewk_74X_4good_l.root', 'out_zzjj_ewk_74X_v2_v5.root', 'Acc_CJLST_eff_gen_ZZ_mass', 'blubb',final_state = '4e')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_74X_v2_v5.root', '4e_EB', '')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_74X_v2_v5.root', '4e', '')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_74X_v2_v5.root', '4m', '')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_74X_v2_v5.root', 'all', '')

# %%
def get_efficieny(file_name, plot_name) :
    teff = get_copy(prefix + file_name, 'raw/' + plot_name)
    total = teff.GetTotalHistogram().Integral()
    passed  = teff.GetPassedHistogram().Integral()

    #print 'passed ', passed
    #print 'total ', total
    return passed / total

# %% [markdown]
# # Efficiencies for ZZ selection

# %%
print 'Within acceptance'
print 'Reconstruction efficiency 4e : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__4e')
print 'Reconstruction efficiency 4m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__4m')
print 'Reconstruction efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__2e2m')
print 'Reconstruction efficiency all : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__all')


print 'Selection efficiency 4e : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_CJLST_eff_gen_ZZ_mass__4e')
print 'Selection efficiency 4m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_CJLST_eff_gen_ZZ_mass__4m')
print 'Selection efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_CJLST_eff_gen_ZZ_mass__2e2m')
print 'Selection efficiency all : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'Acc_CJLST_eff_gen_ZZ_mass__all')
# Out:
# Reconstruction efficiency 4e :  0.725162718472
# Reconstruction efficiency 4m :  0.932768564223
# Reconstruction efficiency 2e2m :  0.826037114394
# Reconstruction efficiency all :  0.826635893132
# Selection efficiency 4e :  0.521070803185
# Selection efficiency 4m :  0.782227991369
# Selection efficiency 2e2m :  0.641633883311
# Selection efficiency all :  0.645551126032

# %%
print 'Selection efficiency 4e : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_CJLST_eff_gen_ZZ_mass__4e')
print 'Selection efficiency 4m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_CJLST_eff_gen_ZZ_mass__4m')
print 'Selection efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_CJLST_eff_gen_ZZ_mass__2e2m')
print 'Selection efficiency all : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_CJLST_eff_gen_ZZ_mass__all')
# Out:
# Selection efficiency 4e :  0.407168614278
# Selection efficiency 4m :  0.590147580339
# Selection efficiency 2e2m :  0.492740555539
# Selection efficiency all :  0.49572259457

# %% [markdown]
# # Efficiencies for BLS selection

# %%
print 'Selection efficiency 4e : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_BLS2_eff_gen_ZZ_mass__4e')
print 'Selection efficiency 4m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_BLS2_eff_gen_ZZ_mass__4m')
print 'Selection efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_BLS2_eff_gen_ZZ_mass__2e2m')
print 'Selection efficiency all : ', get_efficieny('out_zzjj_ewk_74X_v2_v5.root', 'gen_BLS2_eff_gen_ZZ_mass__all')
# Out:
# Selection efficiency 4e :  0.538814423137
# Selection efficiency 4m :  0.652408505124
# Selection efficiency 2e2m :  0.588340931216
# Selection efficiency all :  0.591989693464
