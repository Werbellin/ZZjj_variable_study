# %%
import sys

sys.path.append('/Users/pigard/CMS/ZZ_analysis')

from plot_tools import *
import ROOT
prefix = '/Users/pigard/CMS/ZZ_analysis/'
# Out:
# /Users/pigard/CMS/ZZ_analysis/plot_tools.py:481: SyntaxWarning: import * only allowed at module level
#   def get_y_title(histo, draw_options) :
# Welcome to ROOTaaS 6.05/02

# %% [markdown]
# # NOTE: All counts in the histograms are in fb in the BLS selection
#
#     - Generation cross section: 0.4404 fb
#     - Cross section x accpetance x selection efficiency for CJLST: 0.2177 fb => 0.49432334241 (c.p. 0.49572259457)
#     - Cross section x accpetance x selection efficiency for BLS: 0.1994 fb   => 0.452

# %% [markdown]
# # ZZ mass

# %%
#reload(plot_tools)
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_ZZ_mass'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'blubb'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'no_legend' : True, 'draw_options' : 'BAR'})
# Out:
# {'y_title': '#sigma [fb]', 'no_legend': True, 'draw_options': 'BAR'}
# get_y_title

# %% [markdown]
# # Z kinematics

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z1_mass'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z2_mass'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]',})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]',})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_Z2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.35,.55,.55)})
# Out:
# {'legend_position': (0.4, 0.35, 0.55, 0.55), 'y_title': '#sigma [fb]'}
# get_y_title

# %% [markdown]
# # Muon kinematics

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_3_pT'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_4_pT'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_3_eta'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_mu_4_eta'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %% [markdown]
# # Electrons kinematics

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_3_pT'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_4_pT'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_3_eta'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_4_eta'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_3_phi'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_el_4_phi'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.35,.55,.55)})
# Out:
# {'legend_position': (0.4, 0.35, 0.55, 0.55), 'y_title': '#sigma [fb]'}
# get_y_title

# %% [markdown]
# # Maximum eta among 4l

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_max_4l_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'max 4#ell #eta'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'no_legend' : True})
# Out:
# {'y_title': '#sigma [fb]', 'no_legend': True}
# get_y_title

# %% [markdown]
# # Jet kinemtaics

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_j_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'jet_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_j_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'jet_{2}'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})
# Out:
# {'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_j_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'jet_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_j_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'jet_{2}'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.25,.55,.45)})
# Out:
# {'legend_position': (0.4, 0.25, 0.55, 0.45), 'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_j_1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'jet_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_j_2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'jet_{2}'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.25,.55,.45)})
# Out:
# {'legend_position': (0.4, 0.25, 0.55, 0.45), 'y_title': '#sigma [fb]'}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_tagjet_dEta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : ''}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'no_legend' : True})
# Out:
# {'y_title': '#sigma [fb]', 'no_legend': True}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_tagjet_mass'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : ''}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'no_legend' : True})
# Out:
# {'y_title': '#sigma [fb]', 'no_legend': True}
# get_y_title

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_ewk_74X_v2_v5_better.root', 'tl_BLS/tl_BLS2_tagjet_max_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'max tagjet #eta'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'no_legend' : True})
# Out:
# {'y_title': '#sigma [fb]', 'no_legend': True}
# get_y_title
