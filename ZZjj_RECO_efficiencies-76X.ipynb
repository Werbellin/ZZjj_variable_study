# %%
import sys

sys.path.append('/Users/pigard/CMS/ZZ_analysis')

import ROOT
from plot_tools import *
prefix = '/Users/pigard/CMS/ZZ_analysis/'

# %% [markdown]
# # Fraction of 4 electron events with x electrons in EB

# %%
save_plot([ {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_0EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '0 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_1EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '1 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_2EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '2 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_3EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '3 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_4EB__gen_ZZ_mass__4e'), 
            'draw_options' : {'color' : ROOT.kYellow, 'legend_title' : '4 EB'}}
          ], 
          draw_options = {'y_title' : 'fraction per m_{ZZ} bin', 'draw_option' : 'nostack', 'per_bin_norm' : True})
# Out:
# [<ROOT.TH1F object ("Acc_0EB__gen_ZZ_mass__4e_copy0.924087223201") at 0x7f95fff5f0f0>, <ROOT.TH1F object ("Acc_1EB__gen_ZZ_mass__4e_copy0.745609018263") at 0x7f95fff7a810>, <ROOT.TH1F object ("Acc_2EB__gen_ZZ_mass__4e_copy0.0495327295168") at 0x7f95fff96900>, <ROOT.TH1F object ("Acc_3EB__gen_ZZ_mass__4e_copy0.0363015094067") at 0x7f95ffea6150>, <ROOT.TH1F object ("Acc_4EB__gen_ZZ_mass__4e_copy0.0612948311882") at 0x7f95ffddd6d0>]

# %% [markdown]
# # Fraction of 2 electron events with x electrons in EB

# %%
save_plot([ {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_0EB__gen_ZZ_mass__2e2m'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '0 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_1EB__gen_ZZ_mass__2e2m'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '1 EB'}},
            {'p' : get_plot(prefix + 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'raw/Acc_2EB__gen_ZZ_mass__2e2m'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '2 EB'}},
          ], 
          draw_options = {'y_title' : 'fraction per m_{ZZ} bin', 'draw_option' : 'nostack', 'per_bin_norm' : True})
# Out:
# [<ROOT.TH1F object ("Acc_0EB__gen_ZZ_mass__2e2m_copy0.73311473089") at 0x7f9600027160>, <ROOT.TH1F object ("Acc_1EB__gen_ZZ_mass__2e2m_copy0.732645104521") at 0x7f95ffdbba10>, <ROOT.TH1F object ("Acc_2EB__gen_ZZ_mass__2e2m_copy0.709700738498") at 0x7f96000494e0>]

# %%
def plot_efficiencies_per_final_state(file_name, plot_name, y_title, extra_options = {}) :
    options = {'draw_option' : 'APL'}
    options.update(extra_options)
    save_plot([
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__all'),
           'draw_options' : {'legend_title' : 'sum', 'color' : ROOT.kBlack, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__4m'),
           'draw_options' : {'legend_title' : '4#mu', 'color' : ROOT.kRed, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__2e2m'),
           'draw_options' : {'legend_title' : '2#mu2e', 'color' : ROOT.kBlue, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + plot_name + '__4e'),
           'draw_options' : {'legend_title' : '4e', 'color' : ROOT.kGreen, 'MarkerStyle': 27}},
            ],
               draw_options = options)
    
def plot_selection_step_efficiencies(file_name, final_state, y_title) :
    save_plot([
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'RECO', 'color' : ROOT.kBlack, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isID_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ID', 'color' : ROOT.kBlue, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isISO_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ISO', 'color' : ROOT.kRed, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isISO_isID_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ID and ISO', 'color' : ROOT.kGreen, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_isISO_isID_isSIP_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'ID and ISO and SIP', 'color' : ROOT.kYellow, 'MarkerStyle': 27}},
              ],
               draw_options = {'draw_option' : 'APL', 'legend_position' : (.60,.15,.89,.35)})

# %% [markdown]
# # ZZjj BLS selection efficiency with respect to GEN level:

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_and_BLS_eff_gen_ZZ_mass', 'selection efficiency from GEN')

# %% [markdown]
# # ZZjj VBS selection efficiency with respect to GEN level:

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_and_VBS_eff_gen_ZZ_mass', 'VBS selection efficiency from GEN')

# %% [markdown]
# # ZZjj BLS selection efficiency with respect to the lepton acceptance:
#     - jet acceptance is not included but will be added

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_CJLST_and_BLS_eff_gen_ZZ_mass', 
                                  'BLS selection efficiency in accpetance', {'legend_position' : (.60,.15,.89,.35)})

# %% [markdown]
# # ZZjj VBS selection efficiency with respect to the lepton acceptance:
#     - jet acceptance is not included but will be added

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_74X_v5.root', 'Acc_CJLST_and_VBS_eff_gen_ZZ_mass', 'VBS selection efficiency in accpetance')

# %% [markdown]
# # ZZ selection efficiency from CJLST with respect to GEN level:
#     - this does not include any jet selection

# %%
plot_efficiencies('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_eff_gen_ZZ_mass', 'ZZ selection efficiency for GEN')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-922a3e491810> in <module>()
# ----> 1 plot_efficiencies('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_eff_gen_ZZ_mass', 'ZZ selection efficiency for GEN')
#
# NameError: name 'plot_efficiencies' is not defined

# %% [markdown]
# # ZZ selection efficiency from CJLST with respect to lepton acceptance:

# %%
plot_efficiencies_per_final_state('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_CJLST_eff_gen_ZZ_mass', 
                  'ZZ selection efficiency for GEN', {'legend_position' : (.60,.15,.89,.35)})

# %%
# ZZ selection efficiency from loose lepton CJLST with respect to lepton acceptance:
plot_efficiencies_per_final_state('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass', 
                                  'ZZ selection efficiency for GEN', {'legend_position' : (.60,.15,.89,.35)})

# %% [markdown]
# # Efficiency of ZZjj BLS selection on top of CJLST ZZ slection in lepton acceptance (effect of jj selection)

# %%
def plot_efficiencies_CJLST_to_BLS(file_name, plot_name, y_title, extra_options = {}) :
    options = {'draw_option' : 'APL', 'legend_position' : (.40,.15,.89,.35)}
    options.update(extra_options)
    save_plot([
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_CJLST_eff_gen_ZZ_mass__all'),
           'draw_options' : {'legend_title' : 'ZZ selection', 'color' : ROOT.kBlack, 'MarkerStyle': 27}},
          {'p' :get_eff(prefix + file_name, 'raw/' + 'Acc_CJLST_and_BLS_eff_gen_ZZ_mass__all'),
           'draw_options' : {'legend_title' : 'BLS selection', 'color' : ROOT.kRed, 'MarkerStyle': 27}},

            ],
               draw_options = options)
plot_efficiencies_CJLST_to_BLS('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', '', '')

# %%
def check_eff(file_name1,file_name2, plot_name, y_title, final_state) :
    options = {'draw_option' : 'APL', 'legend_position' : (.40,.15,.89,.35)}
    save_plot([
          {'p' : get_eff(prefix + file_name1, 'raw/Acc_lep_loose_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'regular CLJST', 'color' : ROOT.kBlack, 'MarkerStyle': 17}},
          {'p' : get_eff(prefix + file_name2, 'raw/Acc_CJLST_eff_gen_ZZ_mass__' + final_state),
           'draw_options' : {'legend_title' : 'loose CJLST + ID + ISO + SIP', 'color' : ROOT.kRed, 'MarkerStyle': 27}},
               ],
            draw_options = options)

# %%
check_eff('out_zzjj_ewk_tight_v6_ZZ4lAnalysis.root', 'out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_CJLST_eff_gen_ZZ_mass', 'blubb',final_state = '4e')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', '4e_EB', '')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', '4e', '')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', '4m', '')

# %%
plot_selection_step_efficiencies('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'all', '')

# %%
def get_efficieny(file_name, plot_name) :
    teff = get_copy(prefix + file_name, 'raw/' + plot_name)
    total = teff.GetTotalHistogram().Integral()
    passed  = teff.GetPassedHistogram().Integral()

    #print 'passed ', passed
    #print 'total ', total
    return passed / total

# %% [markdown]
# # Efficiencies for ZZ selection

# %%
print 'Within acceptance'
print 'Reconstruction efficiency 4e : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__4e')
print 'Reconstruction efficiency 4m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__4m')
print 'Reconstruction efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__2e2m')
print 'Reconstruction efficiency all : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_lep_loose_CJLST_eff_gen_ZZ_mass__all')


print 'Selection efficiency 4e : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_CJLST_eff_gen_ZZ_mass__4e')
print 'Selection efficiency 4m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_CJLST_eff_gen_ZZ_mass__4m')
print 'Selection efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_CJLST_eff_gen_ZZ_mass__2e2m')
print 'Selection efficiency all : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'Acc_CJLST_eff_gen_ZZ_mass__all')
# Out:
# Within acceptance
# Reconstruction efficiency 4e :  0.731674091714
# Reconstruction efficiency 4m :  0.941752536979
# Reconstruction efficiency 2e2m :  0.828739427452
# Reconstruction efficiency all :  0.831841169382
# Selection efficiency 4e :  0.564280056306
# Selection efficiency 4m :  0.846221271489
# Selection efficiency 2e2m :  0.688431132334
# Selection efficiency all :  0.695648499021

# %%
print 'Selection efficiency 4e : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_eff_gen_ZZ_mass__4e')
print 'Selection efficiency 4m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_eff_gen_ZZ_mass__4m')
print 'Selection efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_eff_gen_ZZ_mass__2e2m')
print 'Selection efficiency all : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_CJLST_eff_gen_ZZ_mass__all')
# Out:
# Selection efficiency 4e :  0.440847059564
# Selection efficiency 4m :  0.638008409636
# Selection efficiency 2e2m :  0.52875398421
# Selection efficiency all :  0.534111215405

# %% [markdown]
# # Efficiencies for BLS selection

# %%
print 'Selection efficiency 4e : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_BLS2_eff_gen_ZZ_mass__4e')
print 'Selection efficiency 4m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_BLS2_eff_gen_ZZ_mass__4m')
print 'Selection efficiency 2e2m : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_BLS2_eff_gen_ZZ_mass__2e2m')
print 'Selection efficiency all : ', get_efficieny('out_zzjj_ewk_loose_v6_ZZ4lAnalysis.root', 'gen_BLS2_eff_gen_ZZ_mass__all')
# Out:
# Selection efficiency 4e :  0.534605050414
# Selection efficiency 4m :  0.644893307659
# Selection efficiency 2e2m :  0.582745059579
# Selection efficiency all :  0.58625791857
