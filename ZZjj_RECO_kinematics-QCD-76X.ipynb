# %%
import sys

sys.path.append('/Users/pigard/CMS/ZZ_analysis')

from plot_tools import *
import ROOT
prefix = '/Users/pigard/CMS/ZZ_analysis/'
# Out:
# Welcome to ROOTaaS 6.05/02

# %% [markdown]
# # NOTE: All counts in the histograms are in fb
#
#     - Generation cross section: 0.4404 fb
#     - Cross section x accpetance x selection efficiency for CJLST:
#     - Cross section x accpetance x selection efficiency for VBS:

# %% [markdown]
# # ZZ mass

# %%
#reload(plot_tools)
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_ZZ_mass'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_ZZ_mass'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'draw_options' : 'BAR'})

# %% [markdown]
# # Z kinematics

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z1_mass'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z2_mass'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z1_mass'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'Z_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z2_mass'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'Z_{2} VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]',})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z1_pT'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'Z_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z2_pT'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'Z_{2} VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]',})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z1_eta'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'Z_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z2_eta'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'Z_{2} VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'Z_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_Z2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'Z_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z1_phi'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'Z_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_Z2_phi'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'Z_{2} VBS'}}, 
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.35,.55,.55)})

# %% [markdown]
# # Decay angles

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_costhetastar'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_costhetastar'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}}, 
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.65,.55,.85)})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_costheta1'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_costheta1'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}}, 
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.15,.55,.35)})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_costheta2'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_costheta2'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}}, 
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.15,.55,.35)})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_phi'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}}, 
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.15,.55,.35)})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_phi1'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_phi1'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}}, 
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.15,.55,.35)})

# %% [markdown]
# # Muon kinematics

# %% [markdown]
# ## For BLS

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_3_pT'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_4_pT'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_3_eta'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_4_eta'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_3_phi'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_mu_4_phi'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.35,.55,.55)})

# %% [markdown]
# ## For VBS

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_3_pT'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_4_pT'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_3_eta'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_4_eta'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : '#mu_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : '#mu_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_3_phi'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : '#mu_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_mu_4_phi'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : '#mu_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.35,.55,.55)})

# %% [markdown]
# # Electrons kinematics

# %% [markdown]
# ## For BLS

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_3_pT'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_4_pT'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_3_eta'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_4_eta'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_3_phi'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_el_4_phi'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.35,.55,.55)})

# %% [markdown]
# ## For VBS

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_3_pT'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_4_pT'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_3_eta'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_4_eta'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'e_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'e_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_3_phi'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'e_{3}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_el_4_phi'), 
            'draw_options' : {'color' : ROOT.kGreen, 'legend_title' : 'e_{4}'}}
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.35,.55,.55)})

# %% [markdown]
# # Maximum eta among 4l

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_max_4l_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_max_4l_eta'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]','legend_position' : (.35,.75,.25,.88)})

# %% [markdown]
# # Jet kinematics

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_1_pT'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'jet_{1} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_2_pT'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'jet_{2} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_j_1_pT'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'jet_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_j_2_pT'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'jet_{2} VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_1_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'jet_{1}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_2_eta'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'jet_{2}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_j_1_eta'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'jet_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_j_2_eta'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'jet_{2} VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.80,.65,.95,.85)})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_1_phi'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'jet_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_2_phi'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'jet_{2} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_j_1_phi'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'jet_{1} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_j_2_phi'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'jet_{2} VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.40,.25,.55,.45)})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_tagjet_dEta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_tagjet_dEta'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'legend_position' : (.80,.65,.95,.85)})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_tagjet_mass'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_tagjet_mass'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_tagjet_max_eta'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'max #eta tagjet BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_tagjet_max_eta'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'max #eta tagjet VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_n'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'N_{jet}'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_central_j_n'), 
            'draw_options' : {'color' : ROOT.kBlue, 'legend_title' : 'N_{jet} in |#eta| < 2.5'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_ntj_between_tj_n'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'N_{jet} between tagging jets'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'x_title' : 'jet multiplicity'})

# %%
save_plot([{'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_j_n'), 
            'draw_options' : {'color' : ROOT.kRed, 'legend_title' : 'N_{jet} BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_BLS/tl_BLS2_ntj_between_tj_n'), 
            'draw_options' : {'color' : ROOT.kBlack, 'legend_title' : 'N_{jet} between tagging jets BLS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_j_n'), 
            'draw_options' : {'color' : ROOT.kOrange, 'legend_title' : 'N_{jet} VBS'}},
           {'p' : get_plot(prefix + 'out_zzjj_qcd_loose_ZZ4lAnalysis.root', 'tl_VBS/tl_VBS_ntj_between_tj_n'), 
            'draw_options' : {'color' : ROOT.kGray, 'legend_title' : 'N_{jet} between tagging jets VBS'}},
          ], 
          draw_options = {'y_title' : '#sigma [fb]', 'x_title' : 'jet multiplicity'})
